# %%
import csv
import numpy as np
import pandas as pd
import json

# %%
KDs = pd.read_csv("Data/CFSKDsForVisualization.csv")
Modules = pd.read_csv("Data/CFSModulesForVisualization.csv")
Network = pd.read_csv("Data/CFSNetworkForVisualization.csv")
iCave_fd = pd.read_csv("Data/iCave Coordinates - Selim/cfs-net-2-fd-raw.txt", sep='\t', header=None, index_col=0)
iCave_wfd = pd.read_csv("Data/iCave Coordinates - Selim/cfs-net-2-wfd-raw.txt", sep='\t', header=None, index_col=0)

# %%
Network = Network.drop([17485, 17486, 17487, 17488, 17489, 17490, 17491])

# %%
min(list(iCave_wfd[3])), max(list(iCave_wfd[3]))
# Out:
# (-100, 99)

# %% [markdown]
# ### Modules of interest
#
# 1) NKM4
#
# 2) BcellM7
#
# 3) MonoM6
#
# 4) NKM13
#
# 5) NKM9

# %%
NKM4 = []
BcellM7 = []
MonoM6 = []
NKM13 = []
NKM9 = []

for i in range(len(Modules)):
    if Modules["Module"][i] == "NKM4":
        NKM4.append(Modules["GeneName"][i])
    if Modules["Module"][i] == "BcellM7":
        BcellM7.append(Modules["GeneName"][i])
    if Modules["Module"][i] == "MonoM6":
        MonoM6.append(Modules["GeneName"][i])
    if Modules["Module"][i] == "NKM13":
        NKM13.append(Modules["GeneName"][i])
    if Modules["Module"][i] == "NKM9":
        NKM9.append(Modules["GeneName"][i])

# %%
print(len(NKM4), len(BcellM7), len(MonoM6), len(NKM13), len(NKM9))
# Out:
# 92 777 611 202 304

# %%
print(NKM4)
# Out:
# ['ALG2', 'CLP1', 'DBNDD2', 'RGCC', 'PTGER4', 'PABPC4', 'PER1', 'EIF1', 'HSPA5', 'TAF13', 'FAM46C', 'TTC9C', 'RIPK1', 'FOS', 'ZNF674-AS1', 'TNFAIP3', 'PMAIP1', 'MIR22HG', 'RGS2', 'LARP4B', 'MTERFD2', 'SERTAD3', 'WDR53', 'TOE1', 'AC058791.2', 'RNMTL1', 'TSPYL2', 'ARL4A', 'CD83', 'BHLHE40', 'FAM177A1', 'SPRY1', 'IRF1', 'MOAP1', 'EIF1AD', 'EGR2', 'SYS1', 'BNIP1', 'YRDC', 'SRSF7', 'ZNF259', 'KPNA2', 'KANSL2', 'DHRS1', 'CSRNP1', 'ZFP36', 'B3GNT7', 'TNF', 'IRS2', 'TRAF4', 'OTUD1', 'LRRC59', 'AP006216.11', 'ZNF394', 'AVPI1', 'GRASP', 'SPATA2', 'CXCR4', 'CYTIP', 'AC005229.1', 'JUN', 'PIM3', 'DUSP10', 'PPP1R15A', 'C20orf111', 'PDE4B', 'NR4A2', 'DUSP5', 'SLAMF8', 'ATF3', 'DUSP1', 'SLC5A6', 'RP4-800J21.3', 'ZC3H12A', 'BTG2', 'TSPYL1', 'SIK1', 'TP53INP2', 'SPAG4', 'SBDS', 'MAP3K8', 'GRPEL1', 'JMJD6', 'DDIT3', 'MYLIP', 'SERTAD1', 'GADD45A', 'ISG20L2', 'MAFF', 'CTB-31O20.2', 'YPEL5', 'DNAJB1']

# %% [markdown]
# ## Nodes creation

# %%
parents = np.unique(list(Network["ParentGeneName"]))
children = np.unique(list(Network["ChildGeneName"]))

nodes = list(parents) + list(children)
nodes = np.unique(nodes)

## Changing all "." to "-" to match with Selim's files for iCave ##
nodes_mod = []
for i in nodes:
    nodes_mod.append(i.replace(".", "-"))
## Changing all "." to "-" to match with Selim's files for iCave ##

# %%
len(nodes), len(iCave_wfd)
# Out:
# (13305, 13307)

# %%
nodes_and_groups = {}

for i in nodes:
    if i in NKM4:
        nodes_and_groups[i] = "NKM4"
    elif i in BcellM7:
        nodes_and_groups[i] = "BcellM7"
    elif i in MonoM6:
        nodes_and_groups[i] = "MonoM6"
    elif i in NKM13:
        nodes_and_groups[i] = "NKM13"
    elif i in NKM9:
        nodes_and_groups[i] = "NKM9"
    else:
        nodes_and_groups[i] = "none"

# %% [markdown]
# ## Links creation

# %%
links = []
for parent, child in zip(Network["ParentGeneName"], Network["ChildGeneName"]):
    ## Changing all "." to "-" to match with Selim's files for iCave ##
#     parent = parent.replace(".", "-")
#     child = child.replace(".", "-")
    ## Changing all "." to "-" to match with Selim's files for iCave ##
    links.append([parent, child])

# %%
iCave_wfd.rename(index={'100507229':'AL136115-1'}, inplace=True)

# %%
def Diff(li1, li2):
    return (list(list(set(li1)-set(li2)) + list(set(li2)-set(li1))))


iCave_wfd_test = list(iCave_wfd.index)
(Diff(nodes_mod, iCave_wfd_test))
# Out:
# ['MTL5',
#  'LSM7',
#  'SEPTIN4',
#  'VNN2',
#  'ARL11',
#  'LSM6',
#  'ARL15',
#  'MARCHF1',
#  'MLF2',
#  'ARL10',
#  'LSM3',
#  'NPR2',
#  'LSM2',
#  'SEPTIN15',
#  'SOS2',
#  'MARCHF2',
#  'SEPTIN9',
#  'ARL1',
#  'SOS1',
#  'PGK1',
#  'LSM10',
#  'SEPTIN7',
#  'SEPTIN5',
#  'ERN1',
#  'CLP1',
#  'VNN3',
#  'SEPTIN2',
#  'SEPTIN8',
#  'MARCHF8',
#  'LSM12',
#  'ARL3',
#  'BOP1',
#  'LSM1',
#  'TOP1',
#  'MARCHF3',
#  'AMD1',
#  'VNN1',
#  'MDC1',
#  'MAF1',
#  'MARCHF5',
#  'MARCHF6',
#  'ARL16',
#  'PES1',
#  'LSM4',
#  'ARL2',
#  'SEPTIN10',
#  'SIT1',
#  'CYP2E1',
#  'SEPTIN6',
#  'LSM11',
#  'SEPTIN1',
#  'MARCHF7',
#  'MARCHF9',
#  'VNN\xa01-00',
#  'SOS\xa01',
#  'ARL\xa011-00',
#  'SOS\xa02',
#  'PPCS',
#  'MAF\xa01-00',
#  'MARC1',
#  'ARL\xa016-00',
#  'LSM\xa010-00',
#  'MLF\xa02-00',
#  'MARCH5',
#  'SEPT15',
#  'SEPT7',
#  'LSM\xa04-00',
#  'TOP\xa01-00',
#  'CLP\xa01',
#  'LSM\xa07-00',
#  'CYP\xa020-00',
#  'PES\xa01-00',
#  'LSM\xa02-00',
#  'SEPT4',
#  'SEPT1',
#  'SEPT6',
#  'ARL\xa03-00',
#  'ARL\xa01-00',
#  'MARCH7',
#  'NPR\xa02-00',
#  'MARCH1',
#  'ARL\xa010-00',
#  'MARCH6',
#  'MARCH3',
#  'SEPT2',
#  'ARL\xa015-00',
#  'ARL\xa02-00',
#  'LSM\xa06-00',
#  'SEPT9',
#  'MARCH2',
#  'BOP\xa01-00',
#  'ERN\xa01-00',
#  'MARCH9',
#  'MDC\xa01-00',
#  'VNN\xa02-00',
#  'AMD\xa01-00',
#  'PGK\xa01-00',
#  'LSM\xa01-00',
#  'SEPT5',
#  'LSM\xa012-00',
#  'SEPT8',
#  'VNN\xa03-00',
#  'SIT\xa01-00',
#  'LSM\xa03-00',
#  'SEPT10',
#  'MARCH8',
#  'MTL\xa05-00',
#  'LSM\xa011-00']

# %%
without_icave = []
without_node = iCave_wfd_test

for i in nodes_mod:
    if i not in without_node:
        without_icave.append(i)
    if i in without_node:
        without_node.remove(i)

# %%
len(without_icave) , len(without_node)
# Out:
# (53, 55)

# %%
without_icave
# Out:
# ['AMD1',
#  'ARL1',
#  'ARL10',
#  'ARL11',
#  'ARL15',
#  'ARL16',
#  'ARL2',
#  'ARL3',
#  'BOP1',
#  'CLP1',
#  'CYP2E1',
#  'ERN1',
#  'LSM1',
#  'LSM10',
#  'LSM11',
#  'LSM12',
#  'LSM2',
#  'LSM3',
#  'LSM4',
#  'LSM6',
#  'LSM7',
#  'MAF1',
#  'MARCHF1',
#  'MARCHF2',
#  'MARCHF3',
#  'MARCHF5',
#  'MARCHF6',
#  'MARCHF7',
#  'MARCHF8',
#  'MARCHF9',
#  'MDC1',
#  'MLF2',
#  'MTL5',
#  'NPR2',
#  'PES1',
#  'PGK1',
#  'SEPTIN1',
#  'SEPTIN10',
#  'SEPTIN15',
#  'SEPTIN2',
#  'SEPTIN4',
#  'SEPTIN5',
#  'SEPTIN6',
#  'SEPTIN7',
#  'SEPTIN8',
#  'SEPTIN9',
#  'SIT1',
#  'SOS1',
#  'SOS2',
#  'TOP1',
#  'VNN1',
#  'VNN2',
#  'VNN3']

# %%
without_node
# Out:
# ['SEPT7',
#  'MARCH5',
#  'VNN\xa02-00',
#  'ERN\xa01-00',
#  'PES\xa01-00',
#  'SEPT6',
#  'LSM\xa011-00',
#  'LSM\xa07-00',
#  'ARL\xa016-00',
#  'ARL\xa02-00',
#  'MLF\xa02-00',
#  'SEPT4',
#  'SEPT9',
#  'LSM\xa03-00',
#  'ARL\xa015-00',
#  'SEPT2',
#  'SEPT1',
#  'LSM\xa02-00',
#  'ARL\xa011-00',
#  'LSM\xa06-00',
#  'MAF\xa01-00',
#  'MARCH1',
#  'MARCH8',
#  'SOS\xa01',
#  'SIT\xa01-00',
#  'PGK\xa01-00',
#  'ARL\xa03-00',
#  'CLP\xa01',
#  'VNN\xa01-00',
#  'NPR\xa02-00',
#  'MARCH3',
#  'SEPT15',
#  'LSM\xa01-00',
#  'LSM\xa012-00',
#  'SEPT5',
#  'ARL\xa010-00',
#  'SOS\xa02',
#  'MARCH6',
#  'ARL\xa01-00',
#  'MARCH2',
#  'LSM\xa04-00',
#  'VNN\xa03-00',
#  'CYP\xa020-00',
#  'MARCH7',
#  'BOP\xa01-00',
#  'LSM\xa010-00',
#  'TOP\xa01-00',
#  'MARCH9',
#  'MDC\xa01-00',
#  'SEPT8',
#  'SEPT10',
#  'MARC1',
#  'MTL\xa05-00',
#  'AMD\xa01-00',
#  'PPCS']

# %%
## WITH LOCATION FROM ICAVE

final = {"nodes": [], "links": []}

for node in nodes_and_groups:
    final["nodes"] += [{"id": node, "group": nodes_and_groups[node], "location": list(iCave_wfd.loc[node])}]

for parent, child in links:
    final["links"] += [{"source": parent, "target": child, "value": 1}]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AMD1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-ce1fd3fd8e8e> in <module>
#       2
#       3 for node in nodes_and_groups:
# ----> 4     final["nodes"] += [{"id": node, "group": nodes_and_groups[node], "location": list(iCave_wfd.loc[node])}]
#       5
#       6 for parent, child in links:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AMD1'

# %%
## WITHOUT LOCATION FROM ICAVE

final = {"nodes": [], "links": []}

for node in nodes_and_groups:
    final["nodes"] += [{"id": node, "group": nodes_and_groups[node]}]

for parent, child in links:
    final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
final
# Out:
# {'nodes': [{'id': '61E3-4', 'group': 'none'},
#   {'id': 'A1BG-AS1', 'group': 'none'},
#   {'id': 'A2M', 'group': 'none'},
#   {'id': 'A2MP1', 'group': 'none'},
#   {'id': 'AAAS', 'group': 'none'},
#   {'id': 'AACS', 'group': 'none'},
#   {'id': 'AAED1', 'group': 'none'},
#   {'id': 'AAGAB', 'group': 'none'},
#   {'id': 'AAK1', 'group': 'none'},
#   {'id': 'AAMDC', 'group': 'none'},
#   {'id': 'AAMP', 'group': 'none'},
#   {'id': 'AANAT', 'group': 'none'},
#   {'id': 'AAR2', 'group': 'none'},
#   {'id': 'AARS', 'group': 'NKM9'},
#   {'id': 'AARS2', 'group': 'none'},
#   {'id': 'AARSD1', 'group': 'none'},
#   {'id': 'AASDH', 'group': 'none'},
#   {'id': 'AASDHPPT', 'group': 'none'},
#   {'id': 'AASS', 'group': 'none'},
#   {'id': 'AATF', 'group': 'none'},
#   {'id': 'AATK', 'group': 'none'},
#   {'id': 'ABAT', 'group': 'none'},
#   {'id': 'ABC7-42389800N19-1', 'group': 'none'},
#   {'id': 'ABCA1', 'group': 'none'},
#   {'id': 'ABCA10', 'group': 'none'},
#   {'id': 'ABCA13', 'group': 'none'},
#   {'id': 'ABCA2', 'group': 'none'},
#   {'id': 'ABCA3', 'group': 'none'},
#   {'id': 'ABCA5', 'group': 'none'},
#   {'id': 'ABCB1', 'group': 'none'},
#   {'id': 'ABCB6', 'group': 'none'},
#   {'id': 'ABCB7', 'group': 'none'},
#   {'id': 'ABCB8', 'group': 'none'},
#   {'id': 'ABCB9', 'group': 'none'},
#   {'id': 'ABCC1', 'group': 'none'},
#   {'id': 'ABCC10', 'group': 'none'},
#   {'id': 'ABCC13', 'group': 'none'},
#   {'id': 'ABCC2', 'group': 'none'},
#   {'id': 'ABCC3', 'group': 'BcellM7'},
#   {'id': 'ABCC4', 'group': 'none'},
#   {'id': 'ABCC5', 'group': 'none'},
#   {'id': 'ABCC6', 'group': 'none'},
#   {'id': 'ABCD1', 'group': 'none'},
#   {'id': 'ABCD2', 'group': 'none'},
#   {'id': 'ABCD3', 'group': 'none'},
#   {'id': 'ABCD4', 'group': 'none'},
#   {'id': 'ABCF1', 'group': 'none'},
#   {'id': 'ABCF2', 'group': 'MonoM6'},
#   {'id': 'ABCF3', 'group': 'none'},
#   {'id': 'ABCG1', 'group': 'none'},
#   {'id': 'ABHD10', 'group': 'none'},
#   {'id': 'ABHD12', 'group': 'none'},
#   {'id': 'ABHD12B', 'group': 'none'},
#   {'id': 'ABHD13', 'group': 'NKM9'},
#   {'id': 'ABHD14A', 'group': 'none'},
#   {'id': 'ABHD14B', 'group': 'none'},
#   {'id': 'ABHD15', 'group': 'none'},
#   {'id': 'ABHD16A', 'group': 'none'},
#   {'id': 'ABHD16B', 'group': 'none'},
#   {'id': 'ABHD2', 'group': 'none'},
#   {'id': 'ABHD3', 'group': 'none'},
#   {'id': 'ABHD4', 'group': 'none'},
#   {'id': 'ABHD5', 'group': 'BcellM7'},
#   {'id': 'ABHD6', 'group': 'none'},
#   {'id': 'ABHD8', 'group': 'none'},
#   {'id': 'ABI1', 'group': 'none'},
#   {'id': 'ABI2', 'group': 'none'},
#   {'id': 'ABI3', 'group': 'none'},
#   {'id': 'ABL1', 'group': 'none'},
#   {'id': 'ABL2', 'group': 'none'},
#   {'id': 'ABLIM1', 'group': 'none'},
#   {'id': 'ABLIM2', 'group': 'none'},
#   {'id': 'ABLIM3', 'group': 'NKM13'},
#   {'id': 'ABP1', 'group': 'none'},
#   {'id': 'ABR', 'group': 'none'},
#   {'id': 'ABRACL', 'group': 'none'},
#   {'id': 'ABT1', 'group': 'none'},
#   {'id': 'ABTB2', 'group': 'none'},
#   {'id': 'AC000120-7', 'group': 'none'},
#   {'id': 'AC000123-4', 'group': 'none'},
#   {'id': 'AC002055-4', 'group': 'none'},
#   {'id': 'AC002117-1', 'group': 'none'},
#   {'id': 'AC002310-12', 'group': 'none'},
#   {'id': 'AC002511-1', 'group': 'none'},
#   {'id': 'AC002511-2', 'group': 'none'},
#   {'id': 'AC002511-3', 'group': 'none'},
#   {'id': 'AC003104-1', 'group': 'none'},
#   {'id': 'AC003665-1', 'group': 'none'},
#   {'id': 'AC004069-2', 'group': 'none'},
#   {'id': 'AC004166-7', 'group': 'none'},
#   {'id': 'AC004381-6', 'group': 'none'},
#   {'id': 'AC004447-2', 'group': 'none'},
#   {'id': 'AC004453-8', 'group': 'none'},
#   {'id': 'AC004840-9', 'group': 'none'},
#   {'id': 'AC004893-11', 'group': 'none'},
#   {'id': 'AC004906-3', 'group': 'none'},
#   {'id': 'AC004967-11', 'group': 'none'},
#   {'id': 'AC004967-7', 'group': 'none'},
#   {'id': 'AC004967-8', 'group': 'none'},
#   {'id': 'AC004980-7', 'group': 'none'},
#   {'id': 'AC005003-1', 'group': 'none'},
#   {'id': 'AC005077-14', 'group': 'none'},
#   {'id': 'AC005104-3', 'group': 'none'},
#   {'id': 'AC005154-6', 'group': 'none'},
#   {'id': 'AC005154-7', 'group': 'none'},
#   {'id': 'AC005229-1', 'group': 'none'},
#   {'id': 'AC005253-2', 'group': 'none'},
#   {'id': 'AC005329-1', 'group': 'none'},
#   {'id': 'AC005387-2', 'group': 'none'},
#   {'id': 'AC005519-4', 'group': 'none'},
#   {'id': 'AC005562-1', 'group': 'none'},
#   {'id': 'AC005594-3', 'group': 'none'},
#   {'id': 'AC005682-5', 'group': 'none'},
#   {'id': 'AC005785-2', 'group': 'none'},
#   {'id': 'AC005841-1', 'group': 'none'},
#   {'id': 'AC006042-8', 'group': 'none'},
#   {'id': 'AC006116-20', 'group': 'none'},
#   {'id': 'AC006129-2', 'group': 'none'},
#   {'id': 'AC006369-2', 'group': 'none'},
#   {'id': 'AC006465-3', 'group': 'none'},
#   {'id': 'AC006538-1', 'group': 'none'},
#   {'id': 'AC006547-13', 'group': 'none'},
#   {'id': 'AC006547-14', 'group': 'none'},
#   {'id': 'AC006978-6', 'group': 'none'},
#   {'id': 'AC007038-7', 'group': 'none'},
#   {'id': 'AC007246-3', 'group': 'none'},
#   {'id': 'AC007256-5', 'group': 'none'},
#   {'id': 'AC007278-2', 'group': 'none'},
#   {'id': 'AC007278-3', 'group': 'none'},
#   {'id': 'AC007283-5', 'group': 'none'},
#   {'id': 'AC007292-3', 'group': 'none'},
#   {'id': 'AC007292-6', 'group': 'none'},
#   {'id': 'AC007381-2', 'group': 'none'},
#   {'id': 'AC007383-3', 'group': 'none'},
#   {'id': 'AC007383-4', 'group': 'none'},
#   {'id': 'AC007386-2', 'group': 'none'},
#   {'id': 'AC007390-5', 'group': 'none'},
#   {'id': 'AC007464-1', 'group': 'none'},
#   {'id': 'AC007620-3', 'group': 'none'},
#   {'id': 'AC007690-1', 'group': 'none'},
#   {'id': 'AC007879-5', 'group': 'none'},
#   {'id': 'AC008040-1', 'group': 'none'},
#   {'id': 'AC008074-3', 'group': 'none'},
#   {'id': 'AC008443-1', 'group': 'none'},
#   {'id': 'AC008982-2', 'group': 'none'},
#   {'id': 'AC008984-2', 'group': 'none'},
#   {'id': 'AC008984-7', 'group': 'none'},
#   {'id': 'AC009093-1', 'group': 'none'},
#   {'id': 'AC009113-1', 'group': 'none'},
#   {'id': 'AC009120-3', 'group': 'none'},
#   {'id': 'AC009120-5', 'group': 'none'},
#   {'id': 'AC009120-6', 'group': 'none'},
#   {'id': 'AC009133-12', 'group': 'none'},
#   {'id': 'AC009133-14', 'group': 'none'},
#   {'id': 'AC009133-17', 'group': 'none'},
#   {'id': 'AC009303-1', 'group': 'none'},
#   {'id': 'AC009403-2', 'group': 'none'},
#   {'id': 'AC009404-2', 'group': 'none'},
#   {'id': 'AC009495-2', 'group': 'none'},
#   {'id': 'AC009506-1', 'group': 'none'},
#   {'id': 'AC009948-5', 'group': 'none'},
#   {'id': 'AC009950-2', 'group': 'none'},
#   {'id': 'AC009951-1', 'group': 'none'},
#   {'id': 'AC009961-3', 'group': 'none'},
#   {'id': 'AC010492-2', 'group': 'none'},
#   {'id': 'AC010536-1', 'group': 'none'},
#   {'id': 'AC010733-5', 'group': 'none'},
#   {'id': 'AC010761-13', 'group': 'none'},
#   {'id': 'AC010976-2', 'group': 'none'},
#   {'id': 'AC011450-1', 'group': 'none'},
#   {'id': 'AC011475-1', 'group': 'none'},
#   {'id': 'AC011899-9', 'group': 'none'},
#   {'id': 'AC012065-7', 'group': 'none'},
#   {'id': 'AC012307-3', 'group': 'none'},
#   {'id': 'AC012314-19', 'group': 'none'},
#   {'id': 'AC012314-8', 'group': 'none'},
#   {'id': 'AC012318-3', 'group': 'none'},
#   {'id': 'AC012358-4', 'group': 'none'},
#   {'id': 'AC013264-2', 'group': 'none'},
#   {'id': 'AC013400-2', 'group': 'none'},
#   {'id': 'AC015849-15', 'group': 'none'},
#   {'id': 'AC015849-16', 'group': 'none'},
#   {'id': 'AC015849-19', 'group': 'none'},
#   {'id': 'AC015971-2', 'group': 'none'},
#   {'id': 'AC016586-1', 'group': 'none'},
#   {'id': 'AC016629-8', 'group': 'none'},
#   {'id': 'AC016683-6', 'group': 'none'},
#   {'id': 'AC016725-4', 'group': 'none'},
#   {'id': 'AC016735-2', 'group': 'none'},
#   {'id': 'AC016747-3', 'group': 'none'},
#   {'id': 'AC016757-3', 'group': 'none'},
#   {'id': 'AC016773-1', 'group': 'none'},
#   {'id': 'AC017099-3', 'group': 'none'},
#   {'id': 'AC017116-8', 'group': 'none'},
#   {'id': 'AC018638-1', 'group': 'none'},
#   {'id': 'AC018642-1', 'group': 'none'},
#   {'id': 'AC018720-10', 'group': 'none'},
#   {'id': 'AC018737-1', 'group': 'none'},
#   {'id': 'AC018755-15', 'group': 'none'},
#   {'id': 'AC018766-4', 'group': 'none'},
#   {'id': 'AC018766-5', 'group': 'none'},
#   {'id': 'AC018890-6', 'group': 'none'},
#   {'id': 'AC021188-4', 'group': 'none'},
#   {'id': 'AC021860-1', 'group': 'none'},
#   {'id': 'AC022182-3', 'group': 'none'},
#   {'id': 'AC024560-3', 'group': 'none'},
#   {'id': 'AC025171-1', 'group': 'none'},
#   {'id': 'AC025335-1', 'group': 'none'},
#   {'id': 'AC026740-1', 'group': 'none'},
#   {'id': 'AC026806-2', 'group': 'none'},
#   {'id': 'AC027601-1', 'group': 'none'},
#   {'id': 'AC034193-5', 'group': 'none'},
#   {'id': 'AC034220-3', 'group': 'none'},
#   {'id': 'AC055822-1', 'group': 'none'},
#   {'id': 'AC058791-1', 'group': 'none'},
#   {'id': 'AC058791-2', 'group': 'none'},
#   {'id': 'AC067945-4', 'group': 'none'},
#   {'id': 'AC068282-3', 'group': 'none'},
#   {'id': 'AC068491-1', 'group': 'none'},
#   {'id': 'AC068580-6', 'group': 'none'},
#   {'id': 'AC069282-6', 'group': 'none'},
#   {'id': 'AC069513-3', 'group': 'none'},
#   {'id': 'AC073043-2', 'group': 'none'},
#   {'id': 'AC073046-25', 'group': 'none'},
#   {'id': 'AC074117-10', 'group': 'none'},
#   {'id': 'AC074138-3', 'group': 'none'},
#   {'id': 'AC074286-1', 'group': 'none'},
#   {'id': 'AC074289-1', 'group': 'none'},
#   {'id': 'AC078883-3', 'group': 'none'},
#   {'id': 'AC079210-1', 'group': 'none'},
#   {'id': 'AC079305-9', 'group': 'none'},
#   {'id': 'AC079325-6', 'group': 'none'},
#   {'id': 'AC079922-3', 'group': 'none'},
#   {'id': 'AC079949-1', 'group': 'none'},
#   {'id': 'AC083799-1', 'group': 'none'},
#   {'id': 'AC083843-1', 'group': 'none'},
#   {'id': 'AC083863-7', 'group': 'none'},
#   {'id': 'AC083949-1', 'group': 'none'},
#   {'id': 'AC084018-1', 'group': 'none'},
#   {'id': 'AC087163-2', 'group': 'none'},
#   {'id': 'AC087289-1', 'group': 'none'},
#   {'id': 'AC090587-2', 'group': 'none'},
#   {'id': 'AC090587-4', 'group': 'none'},
#   {'id': 'AC091729-9', 'group': 'none'},
#   {'id': 'AC091814-3', 'group': 'none'},
#   {'id': 'AC092171-4', 'group': 'none'},
#   {'id': 'AC092295-7', 'group': 'none'},
#   {'id': 'AC092535-1', 'group': 'none'},
#   {'id': 'AC092620-3', 'group': 'none'},
#   {'id': 'AC092798-2', 'group': 'none'},
#   {'id': 'AC092811-1', 'group': 'none'},
#   {'id': 'AC093162-5', 'group': 'none'},
#   {'id': 'AC093323-3', 'group': 'none'},
#   {'id': 'AC093484-4', 'group': 'none'},
#   {'id': 'AC093495-4', 'group': 'none'},
#   {'id': 'AC093609-1', 'group': 'none'},
#   {'id': 'AC093627-10', 'group': 'none'},
#   {'id': 'AC093627-6', 'group': 'none'},
#   {'id': 'AC093642-3', 'group': 'none'},
#   {'id': 'AC093642-4', 'group': 'none'},
#   {'id': 'AC093642-5', 'group': 'none'},
#   {'id': 'AC093673-5', 'group': 'none'},
#   {'id': 'AC093690-1', 'group': 'none'},
#   {'id': 'AC093726-6', 'group': 'none'},
#   {'id': 'AC093818-1', 'group': 'none'},
#   {'id': 'AC093838-4', 'group': 'none'},
#   {'id': 'AC096772-6', 'group': 'none'},
#   {'id': 'AC097359-1', 'group': 'none'},
#   {'id': 'AC097495-2', 'group': 'none'},
#   {'id': 'AC100830-5', 'group': 'none'},
#   {'id': 'AC103563-9', 'group': 'none'},
#   {'id': 'AC104695-3', 'group': 'none'},
#   {'id': 'AC104809-3', 'group': 'none'},
#   {'id': 'AC104809-4', 'group': 'none'},
#   {'id': 'AC104820-2', 'group': 'none'},
#   {'id': 'AC108463-3', 'group': 'none'},
#   {'id': 'AC108488-3', 'group': 'none'},
#   {'id': 'AC108488-4', 'group': 'none'},
#   {'id': 'AC109826-1', 'group': 'none'},
#   {'id': 'AC109828-1', 'group': 'none'},
#   {'id': 'AC113189-5', 'group': 'none'},
#   {'id': 'AC114772-1', 'group': 'none'},
#   {'id': 'AC115618-1', 'group': 'none'},
#   {'id': 'AC116366-5', 'group': 'none'},
#   {'id': 'AC116366-6', 'group': 'none'},
#   {'id': 'AC118278-1', 'group': 'none'},
#   {'id': 'AC122129-1', 'group': 'none'},
#   {'id': 'AC124944-2', 'group': 'none'},
#   {'id': 'AC125232-1', 'group': 'none'},
#   {'id': 'AC126118-1', 'group': 'none'},
#   {'id': 'AC127496-1', 'group': 'none'},
#   {'id': 'AC127904-2', 'group': 'none'},
#   {'id': 'AC130352-1', 'group': 'none'},
#   {'id': 'AC131097-3', 'group': 'none'},
#   {'id': 'AC131971-1', 'group': 'none'},
#   {'id': 'AC132872-1', 'group': 'none'},
#   {'id': 'AC132872-2', 'group': 'none'},
#   {'id': 'AC133528-2', 'group': 'none'},
#   {'id': 'AC135178-1', 'group': 'none'},
#   {'id': 'AC137932-1', 'group': 'none'},
#   {'id': 'AC137932-5', 'group': 'none'},
#   {'id': 'AC137932-6', 'group': 'none'},
#   {'id': 'AC137934-1', 'group': 'none'},
#   {'id': 'AC141586-5', 'group': 'none'},
#   {'id': 'AC144521-1', 'group': 'none'},
#   {'id': 'AC144831-1', 'group': 'none'},
#   {'id': 'AC147651-3', 'group': 'none'},
#   {'id': 'AC147651-4', 'group': 'none'},
#   {'id': 'ACAA1', 'group': 'none'},
#   {'id': 'ACAA2', 'group': 'none'},
#   {'id': 'ACACA', 'group': 'none'},
#   {'id': 'ACACB', 'group': 'none'},
#   {'id': 'ACAD10', 'group': 'none'},
#   {'id': 'ACAD8', 'group': 'none'},
#   {'id': 'ACAD9', 'group': 'none'},
#   {'id': 'ACADM', 'group': 'none'},
#   {'id': 'ACADS', 'group': 'none'},
#   {'id': 'ACADSB', 'group': 'none'},
#   {'id': 'ACADVL', 'group': 'none'},
#   {'id': 'ACAP1', 'group': 'none'},
#   {'id': 'ACAP2', 'group': 'none'},
#   {'id': 'ACAP2-IT1', 'group': 'none'},
#   {'id': 'ACAP3', 'group': 'none'},
#   {'id': 'ACAT1', 'group': 'none'},
#   {'id': 'ACAT2', 'group': 'none'},
#   {'id': 'ACBD3', 'group': 'none'},
#   {'id': 'ACBD4', 'group': 'none'},
#   {'id': 'ACBD5', 'group': 'none'},
#   {'id': 'ACBD6', 'group': 'none'},
#   {'id': 'ACCS', 'group': 'none'},
#   {'id': 'ACD', 'group': 'none'},
#   {'id': 'ACER2', 'group': 'none'},
#   {'id': 'ACER3', 'group': 'BcellM7'},
#   {'id': 'ACIN1', 'group': 'none'},
#   {'id': 'ACLY', 'group': 'none'},
#   {'id': 'ACN9', 'group': 'none'},
#   {'id': 'ACO1', 'group': 'none'},
#   {'id': 'ACO2', 'group': 'none'},
#   {'id': 'ACOT11', 'group': 'none'},
#   {'id': 'ACOT13', 'group': 'none'},
#   {'id': 'ACOT2', 'group': 'BcellM7'},
#   {'id': 'ACOT8', 'group': 'none'},
#   {'id': 'ACOT9', 'group': 'BcellM7'},
#   {'id': 'ACOX1', 'group': 'none'},
#   {'id': 'ACOX3', 'group': 'none'},
#   {'id': 'ACP1', 'group': 'none'},
#   {'id': 'ACP2', 'group': 'BcellM7'},
#   {'id': 'ACP5', 'group': 'none'},
#   {'id': 'ACP6', 'group': 'none'},
#   {'id': 'ACPL2', 'group': 'none'},
#   {'id': 'ACPP', 'group': 'BcellM7'},
#   {'id': 'ACRBP', 'group': 'BcellM7'},
#   {'id': 'ACRC', 'group': 'none'},
#   {'id': 'ACSF2', 'group': 'none'},
#   {'id': 'ACSF3', 'group': 'none'},
#   {'id': 'ACSL1', 'group': 'BcellM7'},
#   {'id': 'ACSL3', 'group': 'none'},
#   {'id': 'ACSL4', 'group': 'none'},
#   {'id': 'ACSL5', 'group': 'none'},
#   {'id': 'ACSM3', 'group': 'none'},
#   {'id': 'ACSS1', 'group': 'none'},
#   {'id': 'ACSS2', 'group': 'BcellM7'},
#   {'id': 'ACTA2', 'group': 'none'},
#   {'id': 'ACTB', 'group': 'none'},
#   {'id': 'ACTBP2', 'group': 'none'},
#   {'id': 'ACTBP8', 'group': 'none'},
#   {'id': 'ACTG1', 'group': 'none'},
#   {'id': 'ACTG1P10', 'group': 'none'},
#   {'id': 'ACTL10', 'group': 'none'},
#   {'id': 'ACTL6A', 'group': 'none'},
#   {'id': 'ACTN1', 'group': 'BcellM7'},
#   {'id': 'ACTN4', 'group': 'none'},
#   {'id': 'ACTR10', 'group': 'none'},
#   {'id': 'ACTR1A', 'group': 'none'},
#   {'id': 'ACTR1B', 'group': 'none'},
#   {'id': 'ACTR2', 'group': 'none'},
#   {'id': 'ACTR3', 'group': 'none'},
#   {'id': 'ACTR3B', 'group': 'NKM13'},
#   {'id': 'ACTR3C', 'group': 'none'},
#   {'id': 'ACTR5', 'group': 'none'},
#   {'id': 'ACTR6', 'group': 'none'},
#   {'id': 'ACTR8', 'group': 'MonoM6'},
#   {'id': 'ACVR1', 'group': 'NKM13'},
#   {'id': 'ACVR1B', 'group': 'none'},
#   {'id': 'ACVRL1', 'group': 'none'},
#   {'id': 'ACYP1', 'group': 'none'},
#   {'id': 'ACYP2', 'group': 'none'},
#   {'id': 'AD000090-2', 'group': 'none'},
#   {'id': 'AD000092-3', 'group': 'none'},
#   {'id': 'AD000684-2', 'group': 'none'},
#   {'id': 'AD000864-5', 'group': 'none'},
#   {'id': 'ADAL', 'group': 'none'},
#   {'id': 'ADAM10', 'group': 'none'},
#   {'id': 'ADAM15', 'group': 'BcellM7'},
#   {'id': 'ADAM17', 'group': 'none'},
#   {'id': 'ADAM19', 'group': 'none'},
#   {'id': 'ADAM1A', 'group': 'none'},
#   {'id': 'ADAM22', 'group': 'none'},
#   {'id': 'ADAM28', 'group': 'none'},
#   {'id': 'ADAM8', 'group': 'none'},
#   {'id': 'ADAM9', 'group': 'BcellM7'},
#   {'id': 'ADAMTS1', 'group': 'none'},
#   {'id': 'ADAMTS10', 'group': 'none'},
#   {'id': 'ADAMTS13', 'group': 'none'},
#   {'id': 'ADAMTS14', 'group': 'none'},
#   {'id': 'ADAMTS17', 'group': 'none'},
#   {'id': 'ADAMTS4', 'group': 'none'},
#   {'id': 'ADAMTS5', 'group': 'none'},
#   {'id': 'ADAMTS6', 'group': 'none'},
#   {'id': 'ADAMTSL4', 'group': 'BcellM7'},
#   {'id': 'ADAMTSL5', 'group': 'none'},
#   {'id': 'ADAP1', 'group': 'none'},
#   {'id': 'ADAP2', 'group': 'MonoM6'},
#   {'id': 'ADAR', 'group': 'none'},
#   {'id': 'ADARB1', 'group': 'none'},
#   {'id': 'ADAT1', 'group': 'none'},
#   {'id': 'ADAT2', 'group': 'none'},
#   {'id': 'ADAT3', 'group': 'none'},
#   {'id': 'ADC', 'group': 'none'},
#   {'id': 'ADCK1', 'group': 'none'},
#   {'id': 'ADCK2', 'group': 'none'},
#   {'id': 'ADCK3', 'group': 'none'},
#   {'id': 'ADCK4', 'group': 'none'},
#   {'id': 'ADCK5', 'group': 'none'},
#   {'id': 'ADCY10P1', 'group': 'none'},
#   {'id': 'ADCY3', 'group': 'none'},
#   {'id': 'ADCY4', 'group': 'none'},
#   {'id': 'ADCY7', 'group': 'none'},
#   {'id': 'ADCY9', 'group': 'none'},
#   {'id': 'ADD1', 'group': 'BcellM7'},
#   {'id': 'ADD2', 'group': 'MonoM6'},
#   {'id': 'ADD3', 'group': 'none'},
#   {'id': 'ADH5', 'group': 'none'},
#   {'id': 'ADHFE1', 'group': 'none'},
#   {'id': 'ADI1', 'group': 'none'},
#   {'id': 'ADIPOR1', 'group': 'BcellM7'},
#   {'id': 'ADIPOR2', 'group': 'none'},
#   {'id': 'ADK', 'group': 'none'},
#   {'id': 'ADM', 'group': 'none'},
#   {'id': 'ADM2', 'group': 'none'},
#   {'id': 'ADM5', 'group': 'none'},
#   {'id': 'ADNP', 'group': 'none'},
#   {'id': 'ADNP2', 'group': 'none'},
#   {'id': 'ADO', 'group': 'MonoM6'},
#   {'id': 'ADORA2A', 'group': 'none'},
#   {'id': 'ADORA2A-AS1', 'group': 'none'},
#   {'id': 'ADORA2B', 'group': 'none'},
#   {'id': 'ADORA3', 'group': 'MonoM6'},
#   {'id': 'ADPGK', 'group': 'none'},
#   {'id': 'ADPGK-AS1', 'group': 'MonoM6'},
#   {'id': 'ADPRH', 'group': 'none'},
#   {'id': 'ADPRHL2', 'group': 'none'},
#   {'id': 'ADPRM', 'group': 'NKM9'},
#   {'id': 'ADRB2', 'group': 'none'},
#   {'id': 'ADRBK1', 'group': 'none'},
#   {'id': 'ADRBK2', 'group': 'none'},
#   {'id': 'ADRM1', 'group': 'none'},
#   {'id': 'ADSL', 'group': 'none'},
#   {'id': 'ADSSL1', 'group': 'none'},
#   {'id': 'AE000661-37', 'group': 'none'},
#   {'id': 'AEBP1', 'group': 'none'},
#   {'id': 'AEBP2', 'group': 'none'},
#   {'id': 'AEN', 'group': 'MonoM6'},
#   {'id': 'AES', 'group': 'none'},
#   {'id': 'AF001548-5', 'group': 'none'},
#   {'id': 'AF011889-4', 'group': 'none'},
#   {'id': 'AF011889-5', 'group': 'none'},
#   {'id': 'AF127936-7', 'group': 'none'},
#   {'id': 'AF131215-2', 'group': 'none'},
#   {'id': 'AF131216-6', 'group': 'none'},
#   {'id': 'AF131217-1', 'group': 'none'},
#   {'id': 'AF207550-1', 'group': 'none'},
#   {'id': 'AFAP1', 'group': 'none'},
#   {'id': 'AFAP1L2', 'group': 'NKM13'},
#   {'id': 'AFF1', 'group': 'none'},
#   {'id': 'AFF2', 'group': 'none'},
#   {'id': 'AFF3', 'group': 'none'},
#   {'id': 'AFF4', 'group': 'none'},
#   {'id': 'AFG3L1P', 'group': 'none'},
#   {'id': 'AFG3L2', 'group': 'none'},
#   {'id': 'AFMID', 'group': 'none'},
#   {'id': 'AFTPH', 'group': 'none'},
#   {'id': 'AGA', 'group': 'none'},
#   {'id': 'AGAP1', 'group': 'none'},
#   {'id': 'AGAP2', 'group': 'none'},
#   {'id': 'AGAP3', 'group': 'BcellM7'},
#   {'id': 'AGAP4', 'group': 'none'},
#   {'id': 'AGAP6', 'group': 'none'},
#   {'id': 'AGAP7', 'group': 'none'},
#   {'id': 'AGBL2', 'group': 'none'},
#   {'id': 'AGBL3', 'group': 'BcellM7'},
#   {'id': 'AGBL5', 'group': 'NKM13'},
#   {'id': 'AGER', 'group': 'none'},
#   {'id': 'AGFG1', 'group': 'none'},
#   {'id': 'AGFG2', 'group': 'none'},
#   {'id': 'AGGF1', 'group': 'none'},
#   {'id': 'AGK', 'group': 'none'},
#   {'id': 'AGL', 'group': 'none'},
#   {'id': 'AGMAT', 'group': 'none'},
#   {'id': 'AGPAT1', 'group': 'none'},
#   {'id': 'AGPAT2', 'group': 'none'},
#   {'id': 'AGPAT3', 'group': 'BcellM7'},
#   {'id': 'AGPAT4', 'group': 'MonoM6'},
#   {'id': 'AGPAT5', 'group': 'none'},
#   {'id': 'AGPAT6', 'group': 'none'},
#   {'id': 'AGPAT9', 'group': 'none'},
#   {'id': 'AGRN', 'group': 'none'},
#   {'id': 'AGTPBP1', 'group': 'none'},
#   {'id': 'AGTRAP', 'group': 'BcellM7'},
#   {'id': 'AGXT2L2', 'group': 'none'},
#   {'id': 'AHCTF1', 'group': 'none'},
#   {'id': 'AHCY', 'group': 'none'},
#   {'id': 'AHCYL1', 'group': 'none'},
#   {'id': 'AHCYL2', 'group': 'none'},
#   {'id': 'AHDC1', 'group': 'none'},
#   {'id': 'AHNAK', 'group': 'none'},
#   {'id': 'AHNAK2', 'group': 'none'},
#   {'id': 'AHR', 'group': 'BcellM7'},
#   {'id': 'AHSA1', 'group': 'none'},
#   {'id': 'AHSA2', 'group': 'none'},
#   {'id': 'AHSP', 'group': 'none'},
#   {'id': 'AIDA', 'group': 'none'},
#   {'id': 'AIF1', 'group': 'BcellM7'},
#   {'id': 'AIFM1', 'group': 'none'},
#   {'id': 'AIFM3', 'group': 'BcellM7'},
#   {'id': 'AIG1', 'group': 'NKM13'},
#   {'id': 'AIM1', 'group': 'none'},
#   {'id': 'AIM1L', 'group': 'none'},
#   {'id': 'AIM2', 'group': 'none'},
#   {'id': 'AIMP1', 'group': 'none'},
#   {'id': 'AIMP2', 'group': 'MonoM6'},
#   {'id': 'AIP', 'group': 'none'},
#   {'id': 'AIRE', 'group': 'none'},
#   {'id': 'AK1', 'group': 'none'},
#   {'id': 'AK2', 'group': 'none'},
#   {'id': 'AK5', 'group': 'none'},
#   {'id': 'AKAP1', 'group': 'none'},
#   {'id': 'AKAP10', 'group': 'none'},
#   {'id': 'AKAP11', 'group': 'none'},
#   {'id': 'AKAP12', 'group': 'none'},
#   {'id': 'AKAP13', 'group': 'none'},
#   {'id': 'AKAP17A', 'group': 'none'},
#   {'id': 'AKAP2', 'group': 'none'},
#   {'id': 'AKAP5', 'group': 'none'},
#   {'id': 'AKAP6', 'group': 'none'},
#   {'id': 'AKAP7', 'group': 'none'},
#   {'id': 'AKAP8', 'group': 'none'},
#   {'id': 'AKAP8L', 'group': 'none'},
#   {'id': 'AKAP9', 'group': 'none'},
#   {'id': 'AKD1', 'group': 'none'},
#   {'id': 'AKIP1', 'group': 'none'},
#   {'id': 'AKIRIN1', 'group': 'none'},
#   {'id': 'AKIRIN2', 'group': 'none'},
#   {'id': 'AKIRIN2-AS1', 'group': 'MonoM6'},
#   {'id': 'AKNA', 'group': 'none'},
#   {'id': 'AKR1A1', 'group': 'none'},
#   {'id': 'AKR1B1', 'group': 'none'},
#   {'id': 'AKR1C1', 'group': 'none'},
#   {'id': 'AKR1C3', 'group': 'none'},
#   {'id': 'AKR7A2', 'group': 'none'},
#   {'id': 'AKT1', 'group': 'none'},
#   {'id': 'AKT1S1', 'group': 'none'},
#   {'id': 'AKT2', 'group': 'none'},
#   {'id': 'AKT3', 'group': 'none'},
#   {'id': 'AKTIP', 'group': 'none'},
#   {'id': 'AL031320-1', 'group': 'none'},
#   {'id': 'AL049757-3', 'group': 'none'},
#   {'id': 'AL118506-1', 'group': 'none'},
#   {'id': 'AL122127-25', 'group': 'none'},
#   {'id': 'AL122127-3', 'group': 'none'},
#   {'id': 'AL132989-1', 'group': 'none'},
#   {'id': 'AL133458-1', 'group': 'none'},
#   {'id': 'AL136115-1', 'group': 'none'},
#   {'id': 'AL136419-6', 'group': 'none'},
#   {'id': 'AL137059-1', 'group': 'none'},
#   {'id': 'AL137145-1', 'group': 'none'},
#   {'id': 'AL161626-1', 'group': 'none'},
#   {'id': 'AL161915-1', 'group': 'none'},
#   {'id': 'AL353898-2', 'group': 'none'},
#   {'id': 'AL353898-3', 'group': 'none'},
#   {'id': 'AL357673-1', 'group': 'none'},
#   {'id': 'AL358933-1', 'group': 'none'},
#   {'id': 'AL358938-1', 'group': 'none'},
#   {'id': 'AL450992-2', 'group': 'none'},
#   {'id': 'AL512428-1', 'group': 'none'},
#   {'id': 'AL590452-1', 'group': 'none'},
#   {'id': 'AL590560-1', 'group': 'none'},
#   {'id': 'AL590710-2', 'group': 'none'},
#   {'id': 'AL590822-2', 'group': 'none'},
#   {'id': 'AL591025-1', 'group': 'none'},
#   {'id': 'ALAD', 'group': 'none'},
#   {'id': 'ALAS1', 'group': 'MonoM6'},
#   {'id': 'ALAS2', 'group': 'none'},
#   {'id': 'ALCAM', 'group': 'none'},
#   {'id': 'ALDH16A1', 'group': 'none'},
#   {'id': 'ALDH18A1', 'group': 'none'},
#   {'id': 'ALDH1A1', 'group': 'BcellM7'},
#   {'id': 'ALDH1A2', 'group': 'none'},
#   {'id': 'ALDH1B1', 'group': 'none'},
#   {'id': 'ALDH2', 'group': 'BcellM7'},
#   {'id': 'ALDH3A2', 'group': 'none'},
#   {'id': 'ALDH3B1', 'group': 'BcellM7'},
#   {'id': 'ALDH4A1', 'group': 'none'},
#   {'id': 'ALDH5A1', 'group': 'none'},
#   {'id': 'ALDH6A1', 'group': 'none'},
#   {'id': 'ALDH8A1', 'group': 'none'},
#   {'id': 'ALDH9A1', 'group': 'none'},
#   {'id': 'ALDOA', 'group': 'none'},
#   {'id': 'ALDOC', 'group': 'none'},
#   {'id': 'ALG10', 'group': 'none'},
#   {'id': 'ALG10B', 'group': 'none'},
#   {'id': 'ALG11', 'group': 'none'},
#   {'id': 'ALG12', 'group': 'none'},
#   {'id': 'ALG13', 'group': 'none'},
#   {'id': 'ALG1L13P', 'group': 'none'},
#   {'id': 'ALG1L6P', 'group': 'none'},
#   {'id': 'ALG2', 'group': 'NKM4'},
#   {'id': 'ALG3', 'group': 'none'},
#   {'id': 'ALG5', 'group': 'none'},
#   {'id': 'ALG8', 'group': 'none'},
#   {'id': 'ALG9', 'group': 'none'},
#   {'id': 'ALKBH1', 'group': 'none'},
#   {'id': 'ALKBH3', 'group': 'none'},
#   {'id': 'ALKBH4', 'group': 'none'},
#   {'id': 'ALKBH5', 'group': 'none'},
#   {'id': 'ALKBH6', 'group': 'none'},
#   {'id': 'ALKBH7', 'group': 'none'},
#   {'id': 'ALKBH8', 'group': 'none'},
#   {'id': 'ALMS1', 'group': 'none'},
#   {'id': 'ALOX12', 'group': 'NKM13'},
#   {'id': 'ALOX15', 'group': 'none'},
#   {'id': 'ALOX15B', 'group': 'none'},
#   {'id': 'ALOX5', 'group': 'none'},
#   {'id': 'ALOX5AP', 'group': 'none'},
#   {'id': 'ALPK1', 'group': 'none'},
#   {'id': 'ALS2', 'group': 'none'},
#   {'id': 'ALS2CL', 'group': 'none'},
#   {'id': 'ALS2CR12', 'group': 'none'},
#   {'id': 'ALS2CR8', 'group': 'none'},
#   {'id': 'ALYREF', 'group': 'none'},
#   {'id': 'AMACR', 'group': 'none'},
#   {'id': 'AMBRA1', 'group': 'none'},
#   {'id': 'AMD1', 'group': 'NKM9'},
#   {'id': 'AMDHD2', 'group': 'none'},
#   {'id': 'AMFR', 'group': 'none'},
#   {'id': 'AMICA1', 'group': 'BcellM7'},
#   {'id': 'AMIGO1', 'group': 'none'},
#   {'id': 'AMIGO2', 'group': 'none'},
#   {'id': 'AMMECR1', 'group': 'NKM9'},
#   {'id': 'AMMECR1L', 'group': 'none'},
#   {'id': 'AMN', 'group': 'none'},
#   {'id': 'AMN1', 'group': 'none'},
#   {'id': 'AMOT', 'group': 'none'},
#   {'id': 'AMOTL1', 'group': 'none'},
#   {'id': 'AMPD2', 'group': 'BcellM7'},
#   {'id': 'AMPD3', 'group': 'none'},
#   {'id': 'AMPH', 'group': 'none'},
#   {'id': 'AMT', 'group': 'none'},
#   {'id': 'AMY2B', 'group': 'none'},
#   {'id': 'AMZ1', 'group': 'none'},
#   {'id': 'AMZ2', 'group': 'none'},
#   {'id': 'AMZ2P1', 'group': 'MonoM6'},
#   {'id': 'ANAPC1', 'group': 'none'},
#   {'id': 'ANAPC10', 'group': 'none'},
#   {'id': 'ANAPC11', 'group': 'none'},
#   {'id': 'ANAPC13', 'group': 'none'},
#   {'id': 'ANAPC15', 'group': 'none'},
#   {'id': 'ANAPC16', 'group': 'none'},
#   {'id': 'ANAPC2', 'group': 'none'},
#   {'id': 'ANAPC4', 'group': 'none'},
#   {'id': 'ANAPC5', 'group': 'MonoM6'},
#   {'id': 'ANAPC7', 'group': 'none'},
#   {'id': 'ANGEL1', 'group': 'none'},
#   {'id': 'ANGEL2', 'group': 'none'},
#   {'id': 'ANGPT1', 'group': 'none'},
#   {'id': 'ANGPTL1', 'group': 'none'},
#   {'id': 'ANK1', 'group': 'NKM13'},
#   {'id': 'ANKAR', 'group': 'none'},
#   {'id': 'ANKDD1A', 'group': 'none'},
#   {'id': 'ANKFY1', 'group': 'none'},
#   {'id': 'ANKH', 'group': 'none'},
#   {'id': 'ANKHD1', 'group': 'none'},
#   {'id': 'ANKHD1-EIF4EBP3', 'group': 'none'},
#   {'id': 'ANKIB1', 'group': 'none'},
#   {'id': 'ANKLE1', 'group': 'none'},
#   {'id': 'ANKLE2', 'group': 'none'},
#   {'id': 'ANKMY1', 'group': 'none'},
#   {'id': 'ANKMY2', 'group': 'none'},
#   {'id': 'ANKRA2', 'group': 'none'},
#   {'id': 'ANKRD10', 'group': 'none'},
#   {'id': 'ANKRD10-IT1', 'group': 'none'},
#   {'id': 'ANKRD11', 'group': 'none'},
#   {'id': 'ANKRD12', 'group': 'none'},
#   {'id': 'ANKRD13A', 'group': 'none'},
#   {'id': 'ANKRD13B', 'group': 'none'},
#   {'id': 'ANKRD13C', 'group': 'none'},
#   {'id': 'ANKRD13D', 'group': 'none'},
#   {'id': 'ANKRD16', 'group': 'none'},
#   {'id': 'ANKRD17', 'group': 'none'},
#   {'id': 'ANKRD18A', 'group': 'none'},
#   {'id': 'ANKRD18EP', 'group': 'none'},
#   {'id': 'ANKRD19P', 'group': 'none'},
#   {'id': 'ANKRD20A5P', 'group': 'none'},
#   {'id': 'ANKRD22', 'group': 'none'},
#   {'id': 'ANKRD23', 'group': 'none'},
#   {'id': 'ANKRD24', 'group': 'none'},
#   {'id': 'ANKRD26', 'group': 'none'},
#   {'id': 'ANKRD27', 'group': 'none'},
#   {'id': 'ANKRD28', 'group': 'none'},
#   {'id': 'ANKRD30BL', 'group': 'none'},
#   {'id': 'ANKRD32', 'group': 'none'},
#   {'id': 'ANKRD33B', 'group': 'none'},
#   {'id': 'ANKRD34A', 'group': 'none'},
#   {'id': 'ANKRD34B', 'group': 'MonoM6'},
#   {'id': 'ANKRD36', 'group': 'none'},
#   {'id': 'ANKRD36B', 'group': 'none'},
#   {'id': 'ANKRD36BP1', 'group': 'none'},
#   {'id': 'ANKRD36BP2', 'group': 'none'},
#   {'id': 'ANKRD36C', 'group': 'none'},
#   {'id': 'ANKRD37', 'group': 'none'},
#   {'id': 'ANKRD39', 'group': 'none'},
#   {'id': 'ANKRD40', 'group': 'none'},
#   {'id': 'ANKRD42', 'group': 'none'},
#   {'id': 'ANKRD44', 'group': 'none'},
#   {'id': 'ANKRD44-IT1', 'group': 'none'},
#   {'id': 'ANKRD46', 'group': 'none'},
#   {'id': 'ANKRD49', 'group': 'NKM9'},
#   {'id': 'ANKRD50', 'group': 'none'},
#   {'id': 'ANKRD52', 'group': 'none'},
#   {'id': 'ANKRD54', 'group': 'none'},
#   {'id': 'ANKRD55', 'group': 'none'},
#   {'id': 'ANKRD6', 'group': 'none'},
#   {'id': 'ANKRD61', 'group': 'none'},
#   {'id': 'ANKRD9', 'group': 'none'},
#   {'id': 'ANKS1A', 'group': 'none'},
#   {'id': 'ANKS3', 'group': 'none'},
#   {'id': 'ANKS6', 'group': 'none'},
#   {'id': 'ANKZF1', 'group': 'MonoM6'},
#   {'id': 'ANO10', 'group': 'BcellM7'},
#   {'id': 'ANO6', 'group': 'none'},
#   {'id': 'ANO8', 'group': 'BcellM7'},
#   {'id': 'ANO9', 'group': 'none'},
#   {'id': 'ANP32A', 'group': 'none'},
#   {'id': 'ANP32B', 'group': 'none'},
#   {'id': 'ANP32E', 'group': 'none'},
#   {'id': 'ANPEP', 'group': 'BcellM7'},
#   {'id': 'ANTXR2', 'group': 'none'},
#   {'id': 'ANXA1', 'group': 'BcellM7'},
#   {'id': 'ANXA11', 'group': 'none'},
#   {'id': 'ANXA2', 'group': 'none'},
#   {'id': 'ANXA2R', 'group': 'none'},
#   {'id': 'ANXA3', 'group': 'none'},
#   {'id': 'ANXA4', 'group': 'none'},
#   {'id': 'ANXA5', 'group': 'none'},
#   {'id': 'ANXA6', 'group': 'none'},
#   {'id': 'ANXA7', 'group': 'none'},
#   {'id': 'ANXA9', 'group': 'none'},
#   {'id': 'AOAH', 'group': 'BcellM7'},
#   {'id': 'AOAH-IT1', 'group': 'none'},
#   {'id': 'AP000295-7', 'group': 'none'},
#   {'id': 'AP000640-10', 'group': 'none'},
#   {'id': 'AP000640-8', 'group': 'none'},
#   {'id': 'AP000783-1', 'group': 'none'},
#   {'id': 'AP001007-1', 'group': 'none'},
#   {'id': 'AP001053-11', 'group': 'none'},
#   {'id': 'AP001055-6', 'group': 'none'},
#   {'id': 'AP001056-1', 'group': 'none'},
#   {'id': 'AP001062-7', 'group': 'none'},
#   {'id': 'AP001187-2', 'group': 'none'},
#   {'id': 'AP001189-4', 'group': 'none'},
#   {'id': 'AP001205-1', 'group': 'none'},
#   {'id': 'AP001258-4', 'group': 'none'},
#   {'id': 'AP001468-1', 'group': 'none'},
#   {'id': 'AP001469-9', 'group': 'none'},
#   {'id': 'AP001816-1', 'group': 'none'},
#   {'id': 'AP001877-1', 'group': 'none'},
#   {'id': 'AP001885-1', 'group': 'none'},
#   {'id': 'AP003068-18', 'group': 'none'},
#   {'id': 'AP003068-23', 'group': 'none'},
#   {'id': 'AP003068-6', 'group': 'none'},
#   {'id': 'AP003733-1', 'group': 'none'},
#   {'id': 'AP003774-1', 'group': 'none'},
#   {'id': 'AP003774-4', 'group': 'none'},
#   {'id': 'AP003774-6', 'group': 'none'},
#   {'id': 'AP006216-11', 'group': 'none'},
#   {'id': 'AP006222-2', 'group': 'none'},
#   {'id': 'AP006621-1', 'group': 'none'},
#   {'id': 'AP006621-5', 'group': 'none'},
#   {'id': 'AP1AR', 'group': 'none'},
#   {'id': 'AP1B1', 'group': 'none'},
#   {'id': 'AP1G1', 'group': 'none'},
#   {'id': 'AP1G2', 'group': 'none'},
#   {'id': 'AP1M1', 'group': 'none'},
#   {'id': 'AP1M2', 'group': 'none'},
#   {'id': 'AP1S2', 'group': 'BcellM7'},
#   {'id': 'AP1S3', 'group': 'none'},
#   {'id': 'AP2A1', 'group': 'BcellM7'},
#   {'id': 'AP2A2', 'group': 'none'},
#   {'id': 'AP2B1', 'group': 'none'},
#   {'id': 'AP2M1', 'group': 'none'},
#   {'id': 'AP2S1', 'group': 'none'},
#   {'id': 'AP3B1', 'group': 'none'},
#   {'id': 'AP3D1', 'group': 'none'},
#   {'id': 'AP3M1', 'group': 'none'},
#   {'id': 'AP3M2', 'group': 'none'},
#   {'id': 'AP3S1', 'group': 'none'},
#   {'id': 'AP3S2', 'group': 'MonoM6'},
#   {'id': 'AP4B1', 'group': 'none'},
#   {'id': 'AP4B1-AS1', 'group': 'none'},
#   {'id': 'AP4E1', 'group': 'none'},
#   {'id': 'AP4M1', 'group': 'none'},
#   {'id': 'AP4S1', 'group': 'BcellM7'},
#   {'id': 'AP5B1', 'group': 'BcellM7'},
#   {'id': 'AP5M1', 'group': 'none'},
#   {'id': 'AP5S1', 'group': 'none'},
#   {'id': 'AP5Z1', 'group': 'none'},
#   {'id': 'APAF1', 'group': 'none'},
#   {'id': 'APBA2', 'group': 'none'},
#   {'id': 'APBA3', 'group': 'none'},
#   {'id': 'APBB1', 'group': 'none'},
#   {'id': 'APBB1IP', 'group': 'none'},
#   {'id': 'APBB2', 'group': 'none'},
#   {'id': 'APBB3', 'group': 'none'},
#   {'id': 'APC', 'group': 'none'},
#   {'id': 'APC2', 'group': 'none'},
#   {'id': 'APCDD1', 'group': 'none'},
#   {'id': 'APEH', 'group': 'none'},
#   {'id': 'APEX1', 'group': 'none'},
#   {'id': 'APEX2', 'group': 'none'},
#   {'id': 'APH1A', 'group': 'none'},
#   {'id': 'APH1B', 'group': 'none'},
#   {'id': 'API5', 'group': 'none'},
#   {'id': 'APIP', 'group': 'none'},
#   {'id': 'APLP2', 'group': 'none'},
#   {'id': 'APMAP', 'group': 'none'},
#   {'id': 'APOA1BP', 'group': 'none'},
#   {'id': 'APOBEC3A', 'group': 'BcellM7'},
#   {'id': 'APOBEC3B', 'group': 'none'},
#   {'id': 'APOBEC3C', 'group': 'none'},
#   {'id': 'APOBEC3D', 'group': 'BcellM7'},
#   {'id': 'APOBEC3F', 'group': 'none'},
#   {'id': 'APOBEC3G', 'group': 'none'},
#   {'id': 'APOBR', 'group': 'BcellM7'},
#   {'id': 'APOL1', 'group': 'none'},
#   {'id': 'APOL2', 'group': 'MonoM6'},
#   {'id': 'APOL3', 'group': 'MonoM6'},
#   {'id': 'APOL4', 'group': 'MonoM6'},
#   {'id': 'APOLD1', 'group': 'none'},
#   {'id': 'APOM', 'group': 'none'},
#   {'id': 'APOO', 'group': 'none'},
#   {'id': 'APOOL', 'group': 'none'},
#   {'id': 'APP', 'group': 'NKM13'},
#   {'id': 'APPBP2', 'group': 'none'},
#   {'id': 'APPL1', 'group': 'none'},
#   {'id': 'APPL2', 'group': 'none'},
#   {'id': 'APRT', 'group': 'none'},
#   {'id': 'APTX', 'group': 'none'},
#   {'id': 'AQP11', 'group': 'none'},
#   {'id': 'AQP3', 'group': 'none'},
#   {'id': 'AQP9', 'group': 'BcellM7'},
#   {'id': 'AQR', 'group': 'none'},
#   {'id': 'ARAP1', 'group': 'none'},
#   {'id': 'ARAP1-AS2', 'group': 'none'},
#   {'id': 'ARAP2', 'group': 'none'},
#   {'id': 'ARAP3', 'group': 'BcellM7'},
#   {'id': 'ARCN1', 'group': 'none'},
#   {'id': 'ARF1', 'group': 'none'},
#   {'id': 'ARF3', 'group': 'none'},
#   {'id': 'ARF4', 'group': 'none'},
#   {'id': 'ARF5', 'group': 'none'},
#   {'id': 'ARFGAP1', 'group': 'none'},
#   {'id': 'ARFGAP2', 'group': 'MonoM6'},
#   {'id': 'ARFGAP3', 'group': 'none'},
#   {'id': 'ARFGEF1', 'group': 'none'},
#   {'id': 'ARFGEF2', 'group': 'none'},
#   {'id': 'ARFIP1', 'group': 'none'},
#   {'id': 'ARFIP2', 'group': 'none'},
#   {'id': 'ARFRP1', 'group': 'none'},
#   {'id': 'ARG1', 'group': 'none'},
#   {'id': 'ARG2', 'group': 'NKM13'},
#   {'id': 'ARGLU1', 'group': 'none'},
#   {'id': 'ARHGAP1', 'group': 'none'},
#   {'id': 'ARHGAP10', 'group': 'none'},
#   {'id': 'ARHGAP11A', 'group': 'none'},
#   {'id': 'ARHGAP11B', 'group': 'none'},
#   {'id': 'ARHGAP12', 'group': 'NKM9'},
#   {'id': 'ARHGAP15', 'group': 'none'},
#   {'id': 'ARHGAP17', 'group': 'none'},
#   {'id': 'ARHGAP18', 'group': 'none'},
#   {'id': 'ARHGAP19', 'group': 'none'},
#   {'id': 'ARHGAP21', 'group': 'none'},
#   {'id': 'ARHGAP22', 'group': 'none'},
#   {'id': 'ARHGAP24', 'group': 'none'},
#   {'id': 'ARHGAP25', 'group': 'none'},
#   {'id': 'ARHGAP26', 'group': 'BcellM7'},
#   {'id': 'ARHGAP27', 'group': 'none'},
#   {'id': 'ARHGAP30', 'group': 'none'},
#   {'id': 'ARHGAP31', 'group': 'none'},
#   {'id': 'ARHGAP33', 'group': 'none'},
#   {'id': 'ARHGAP35', 'group': 'none'},
#   {'id': 'ARHGAP39', 'group': 'none'},
#   {'id': 'ARHGAP44', 'group': 'none'},
#   {'id': 'ARHGAP5', 'group': 'none'},
#   {'id': 'ARHGAP6', 'group': 'NKM13'},
#   {'id': 'ARHGAP8', 'group': 'none'},
#   {'id': 'ARHGAP9', 'group': 'none'},
#   {'id': 'ARHGDIA', 'group': 'none'},
#   {'id': 'ARHGDIB', 'group': 'none'},
#   {'id': 'ARHGEF1', 'group': 'none'},
#   {'id': 'ARHGEF10', 'group': 'none'},
#   {'id': 'ARHGEF10L', 'group': 'BcellM7'},
#   {'id': 'ARHGEF11', 'group': 'BcellM7'},
#   {'id': 'ARHGEF12', 'group': 'none'},
#   {'id': 'ARHGEF18', 'group': 'none'},
#   {'id': 'ARHGEF19', 'group': 'none'},
#   {'id': 'ARHGEF2', 'group': 'none'},
#   {'id': 'ARHGEF25', 'group': 'none'},
#   {'id': 'ARHGEF3', 'group': 'none'},
#   {'id': 'ARHGEF39', 'group': 'none'},
#   {'id': 'ARHGEF40', 'group': 'BcellM7'},
#   {'id': 'ARHGEF5', 'group': 'BcellM7'},
#   {'id': 'ARHGEF6', 'group': 'none'},
#   {'id': 'ARHGEF7', 'group': 'none'},
#   {'id': 'ARHGEF9', 'group': 'none'},
#   {'id': 'ARID1A', 'group': 'none'},
#   {'id': 'ARID1B', 'group': 'none'},
#   {'id': 'ARID2', 'group': 'none'},
#   {'id': 'ARID3A', 'group': 'none'},
#   {'id': 'ARID3B', 'group': 'none'},
#   {'id': 'ARID4A', 'group': 'NKM9'},
#   {'id': 'ARID4B', 'group': 'none'},
#   {'id': 'ARID5A', 'group': 'none'},
#   {'id': 'ARID5B', 'group': 'none'},
#   {'id': 'ARIH1', 'group': 'none'},
#   {'id': 'ARIH2', 'group': 'none'},
#   {'id': 'ARIH2OS', 'group': 'none'},
#   {'id': 'ARL1', 'group': 'none'},
#   {'id': 'ARL10', 'group': 'none'},
#   {'id': 'ARL11', 'group': 'none'},
#   {'id': 'ARL13B', 'group': 'none'},
#   {'id': 'ARL14EP', 'group': 'BcellM7'},
#   {'id': 'ARL15', 'group': 'none'},
#   {'id': 'ARL16', 'group': 'none'},
#   {'id': 'ARL17A', 'group': 'none'},
#   {'id': 'ARL17B', 'group': 'none'},
#   {'id': 'ARL2', 'group': 'none'},
#   {'id': 'ARL2BP', 'group': 'none'},
#   {'id': 'ARL3', 'group': 'none'},
#   {'id': 'ARL4A', 'group': 'NKM4'},
#   {'id': 'ARL4C', 'group': 'MonoM6'},
#   {'id': 'ARL5A', 'group': 'none'},
#   {'id': 'ARL5B', 'group': 'NKM9'},
#   {'id': 'ARL6IP1', 'group': 'none'},
#   {'id': 'ARL6IP5', 'group': 'none'},
#   {'id': 'ARL6IP6', 'group': 'none'},
#   {'id': 'ARL8A', 'group': 'none'},
#   {'id': 'ARL8B', 'group': 'none'},
#   {'id': 'ARMC10', 'group': 'none'},
#   {'id': 'ARMC2', 'group': 'MonoM6'},
#   {'id': 'ARMC5', 'group': 'none'},
#   {'id': 'ARMC6', 'group': 'none'},
#   {'id': 'ARMC7', 'group': 'none'},
#   {'id': 'ARMC8', 'group': 'none'},
#   {'id': 'ARMCX2', 'group': 'BcellM7'},
#   {'id': 'ARMCX3', 'group': 'none'},
#   {'id': 'ARMCX4', 'group': 'none'},
#   {'id': 'ARMCX5', 'group': 'NKM9'},
#   {'id': 'ARMCX6', 'group': 'none'},
#   {'id': 'ARNT', 'group': 'none'},
#   {'id': 'ARNTL', 'group': 'none'},
#   {'id': 'ARPC1A', 'group': 'none'},
#   {'id': 'ARPC1B', 'group': 'none'},
#   {'id': 'ARPC2', 'group': 'none'},
#   {'id': 'ARPC3', 'group': 'none'},
#   {'id': 'ARPC4', 'group': 'none'},
#   {'id': 'ARPC5', 'group': 'none'},
#   {'id': 'ARPC5L', 'group': 'none'},
#   {'id': 'ARPP19', 'group': 'none'},
#   {'id': 'ARRB1', 'group': 'BcellM7'},
#   {'id': 'ARRB2', 'group': 'BcellM7'},
#   {'id': 'ARRDC2', 'group': 'none'},
#   {'id': 'ARRDC3', 'group': 'none'},
#   {'id': 'ARRDC4', 'group': 'none'},
#   {'id': 'ARSA', 'group': 'none'},
#   {'id': 'ARSB', 'group': 'BcellM7'},
#   {'id': 'ARSD', 'group': 'BcellM7'},
#   {'id': 'ARSG', 'group': 'none'},
#   {'id': 'ARSK', 'group': 'none'},
#   {'id': 'ARV1', 'group': 'none'},
#   {'id': 'ARVCF', 'group': 'none'},
#   {'id': 'AS3MT', 'group': 'none'},
#   {'id': 'ASAH1', 'group': 'none'},
#   {'id': 'ASAP1', 'group': 'none'},
#   {'id': 'ASAP2', 'group': 'none'},
#   {'id': 'ASAP3', 'group': 'none'},
#   {'id': 'ASB1', 'group': 'none'},
#   {'id': 'ASB13', 'group': 'none'},
#   {'id': 'ASB16', 'group': 'none'},
#   {'id': 'ASB2', 'group': 'none'},
#   {'id': 'ASB3', 'group': 'none'},
#   ...],
#  'links': [{'source': 'GCLC', 'target': 'PSME4', 'value': 1},
#   {'source': 'LAS1L', 'target': 'NSUN2', 'value': 1},
#   {'source': 'LASP1', 'target': 'RAC2', 'value': 1},
#   {'source': 'LASP1', 'target': 'RASSF5', 'value': 1},
#   {'source': 'LASP1', 'target': 'ARF3', 'value': 1},
#   {'source': 'LASP1', 'target': 'SPRED2', 'value': 1},
#   {'source': 'LASP1', 'target': 'ACTR10', 'value': 1},
#   {'source': 'M6PR', 'target': 'PDIA6', 'value': 1},
#   {'source': 'CFLAR', 'target': 'KIAA0556', 'value': 1},
#   {'source': 'CFLAR', 'target': 'Metazoa_SRP', 'value': 1},
#   {'source': 'CFLAR', 'target': 'AC007283.5', 'value': 1},
#   {'source': 'CFLAR', 'target': 'SLC16A1', 'value': 1},
#   {'source': 'RBM6', 'target': 'REV1', 'value': 1},
#   {'source': 'FAM214B', 'target': 'C17orf103', 'value': 1},
#   {'source': 'FAM214B', 'target': 'WDR45', 'value': 1},
#   {'source': 'FBXL3', 'target': 'DR1', 'value': 1},
#   {'source': 'FBXL3', 'target': 'LCOR', 'value': 1},
#   {'source': 'FBXL3', 'target': 'FOXN2', 'value': 1},
#   {'source': 'SYNRG', 'target': 'DCAF5', 'value': 1},
#   {'source': 'SYNRG', 'target': 'ZBED2', 'value': 1},
#   {'source': 'SYNRG', 'target': 'FAM115C', 'value': 1},
#   {'source': 'SYNRG', 'target': 'ABL2', 'value': 1},
#   {'source': 'DBF4', 'target': 'FKBP3', 'value': 1},
#   {'source': 'PAFAH1B1', 'target': 'ZNF398', 'value': 1},
#   {'source': 'MPND', 'target': 'PRR22', 'value': 1},
#   {'source': 'IL32', 'target': 'CD2', 'value': 1},
#   {'source': 'RPS20', 'target': 'RP11-85K15.2', 'value': 1},
#   {'source': 'RPS20', 'target': 'GAS5', 'value': 1},
#   {'source': 'RPS20', 'target': 'MRPL32', 'value': 1},
#   {'source': 'RPS20', 'target': 'SNN', 'value': 1},
#   {'source': 'RPS20', 'target': 'RPS8', 'value': 1},
#   {'source': 'CSDE1', 'target': 'TERF2IP', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'KIAA0907', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'GLUL', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'MINOS1', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'ZNF587B', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'AC013264.2', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'BCS1L', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'ACYP2', 'value': 1},
#   {'source': 'TRAF3IP3', 'target': 'ACRC', 'value': 1},
#   {'source': 'IFFO1', 'target': 'SDF4', 'value': 1},
#   {'source': 'IFFO1', 'target': 'KCNK6', 'value': 1},
#   {'source': 'IFFO1', 'target': 'CTB-55O6.12', 'value': 1},
#   {'source': 'IFFO1', 'target': 'BRSK2', 'value': 1},
#   {'source': 'STAB1', 'target': 'ASGR2', 'value': 1},
#   {'source': 'STAB1', 'target': 'CARD9', 'value': 1},
#   {'source': 'STAB1', 'target': 'TBC1D2', 'value': 1},
#   {'source': 'STAB1', 'target': 'GPR162', 'value': 1},
#   {'source': 'CD4', 'target': 'VASH1', 'value': 1},
#   {'source': 'CD4', 'target': 'TICAM1', 'value': 1},
#   {'source': 'CD4', 'target': 'GPR35', 'value': 1},
#   {'source': 'BTK', 'target': 'C1orf162', 'value': 1},
#   {'source': 'APBA3', 'target': 'MEPCE', 'value': 1},
#   {'source': 'PLAUR', 'target': 'RP11-44F14.2', 'value': 1},
#   {'source': 'PLAUR', 'target': 'MSRB1', 'value': 1},
#   {'source': 'WIZ', 'target': 'GNPTG', 'value': 1},
#   {'source': 'WIZ', 'target': 'TEAD2', 'value': 1},
#   {'source': 'CD22', 'target': 'CD79A', 'value': 1},
#   {'source': 'CD22', 'target': 'SIPA1L3', 'value': 1},
#   {'source': 'CD22', 'target': 'GYLTL1B', 'value': 1},
#   {'source': 'CD22', 'target': 'SWAP70', 'value': 1},
#   {'source': 'CD22', 'target': 'RP11-358M11.2', 'value': 1},
#   {'source': 'CD22', 'target': 'FAM129C', 'value': 1},
#   {'source': 'CD22', 'target': 'FCRL1', 'value': 1},
#   {'source': 'CD22', 'target': 'COL19A1', 'value': 1},
#   {'source': 'CD22', 'target': 'RP11-420G6.4', 'value': 1},
#   {'source': 'CD22', 'target': 'PAX5', 'value': 1},
#   {'source': 'PSMC4', 'target': 'EIF4A3', 'value': 1},
#   {'source': 'MAN2B2', 'target': 'CTD-3099C6.11', 'value': 1},
#   {'source': 'MAN2B2', 'target': 'SCAMP2', 'value': 1},
#   {'source': 'MAN2B2', 'target': 'SNX33', 'value': 1},
#   {'source': 'NUB1', 'target': 'SP140', 'value': 1},
#   {'source': 'XYLT2', 'target': 'DEGS2', 'value': 1},
#   {'source': 'XYLT2', 'target': 'LONP1', 'value': 1},
#   {'source': 'XYLT2', 'target': 'ZNF580', 'value': 1},
#   {'source': 'XYLT2', 'target': 'CTC-205M6.2', 'value': 1},
#   {'source': 'CD74', 'target': 'CD37', 'value': 1},
#   {'source': 'CD74', 'target': 'HLA-DMA', 'value': 1},
#   {'source': 'CD74', 'target': 'RHBDF2', 'value': 1},
#   {'source': 'RUNX3', 'target': 'IL2RB', 'value': 1},
#   {'source': 'RUNX3', 'target': 'CEP250', 'value': 1},
#   {'source': 'RUNX3', 'target': 'SMAD7', 'value': 1},
#   {'source': 'RUNX3', 'target': 'SYT11', 'value': 1},
#   {'source': 'RUNX3', 'target': 'TTC22', 'value': 1},
#   {'source': 'RUNX3', 'target': 'GPR114', 'value': 1},
#   {'source': 'RUNX3', 'target': 'CHST12', 'value': 1},
#   {'source': 'RUNX3', 'target': 'TBX21', 'value': 1},
#   {'source': 'RUNX3', 'target': 'PRR5L', 'value': 1},
#   {'source': 'RUNX3', 'target': 'NPC1', 'value': 1},
#   {'source': 'RUNX3', 'target': 'DLG5', 'value': 1},
#   {'source': 'RUNX3', 'target': 'ADCY9', 'value': 1},
#   {'source': 'PLEKHB1', 'target': 'GPR113', 'value': 1},
#   {'source': 'PLEKHB1', 'target': 'NTN5', 'value': 1},
#   {'source': 'PRKCH', 'target': 'NEO1', 'value': 1},
#   {'source': 'PRKCH', 'target': 'KDELC2', 'value': 1},
#   {'source': 'PRKCH', 'target': 'FYN', 'value': 1},
#   {'source': 'PRKCH', 'target': 'CD247', 'value': 1},
#   {'source': 'PRKCH', 'target': 'LGALSL', 'value': 1},
#   {'source': 'PRKCH', 'target': 'OTUD7B', 'value': 1},
#   {'source': 'PRKCH', 'target': 'SLFN12L', 'value': 1},
#   {'source': 'PRKCH', 'target': 'ELAC2', 'value': 1},
#   {'source': 'PRKCH', 'target': 'PRKCQ', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'EXOC1', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'PIGA', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'R3HCC1L', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'RIF1', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'YTHDC1', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'RBM25', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'UBA6', 'value': 1},
#   {'source': 'BCLAF1', 'target': 'SEPTIN7', 'value': 1},
#   {'source': 'NUP160', 'target': 'ANAPC4', 'value': 1},
#   {'source': 'NUP160', 'target': 'SFMBT1', 'value': 1},
#   {'source': 'ARID4A', 'target': 'RAB18', 'value': 1},
#   {'source': 'ARID4A', 'target': 'ERGIC2', 'value': 1},
#   {'source': 'ARID4A', 'target': 'ANKRD12', 'value': 1},
#   {'source': 'ARID4A', 'target': 'ROCK1', 'value': 1},
#   {'source': 'ARID4A', 'target': 'NDUFAF3', 'value': 1},
#   {'source': 'ARID4A', 'target': 'ARID4B', 'value': 1},
#   {'source': 'PNPLA6', 'target': 'CTIF', 'value': 1},
#   {'source': 'PNPLA6', 'target': 'RNPEPL1', 'value': 1},
#   {'source': 'PNPLA6', 'target': 'TRAF7', 'value': 1},
#   {'source': 'PNPLA6', 'target': 'ZNRF1', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'WWP1', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ARMCX5', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'SPAG16', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ANKRD46', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'SLC39A10', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'SC5DL', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'C3orf17', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ANGEL2', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'FBXO22', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'SNHG14', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'TUBE1', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'FAM69A', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'STYX', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'C10orf88', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ZNF571', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'WDR36', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ZNF354B', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'TRPM7', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'CASD1', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'DPY19L4', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ACADSB', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ZNF529', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'ZNF559', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'RBM45', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'URI1', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'MRPL42', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'FZD6', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'LRPPRC', 'value': 1},
#   {'source': 'ZZZ3', 'target': 'VEZT', 'value': 1},
#   {'source': 'NSUN2', 'target': 'MKS1', 'value': 1},
#   {'source': 'NSUN2', 'target': 'TRUB2', 'value': 1},
#   {'source': 'FBXO42', 'target': 'KIF3B', 'value': 1},
#   {'source': 'MFAP3', 'target': 'RBM18', 'value': 1},
#   {'source': 'MRI1', 'target': 'FAHD2CP', 'value': 1},
#   {'source': 'VCAN', 'target': 'CYP1B1', 'value': 1},
#   {'source': 'VCAN', 'target': 'ANKRD50', 'value': 1},
#   {'source': 'VCAN', 'target': 'CYBB', 'value': 1},
#   {'source': 'VCAN', 'target': 'KCTD12', 'value': 1},
#   {'source': 'VCAN', 'target': 'RPL7AP64', 'value': 1},
#   {'source': 'VCAN', 'target': 'RP11-356N1.2', 'value': 1},
#   {'source': 'VCAN', 'target': 'SGMS2', 'value': 1},
#   {'source': 'VCAN', 'target': 'FAM198B', 'value': 1},
#   {'source': 'VCAN', 'target': 'RXFP2', 'value': 1},
#   {'source': 'CLEC16A', 'target': 'C20orf196', 'value': 1},
#   {'source': 'CLEC16A', 'target': 'WHSC1', 'value': 1},
#   {'source': 'PHF15', 'target': 'CRTC1', 'value': 1},
#   {'source': 'PHF15', 'target': 'PLXNA1', 'value': 1},
#   {'source': 'PHF15', 'target': 'FAM78A', 'value': 1},
#   {'source': 'PHF15', 'target': 'TATDN2', 'value': 1},
#   {'source': 'PHF15', 'target': 'HEATR2', 'value': 1},
#   {'source': 'PHF15', 'target': 'INTS5', 'value': 1},
#   {'source': 'PHF15', 'target': 'ZNF71', 'value': 1},
#   {'source': 'PHF15', 'target': 'JRK', 'value': 1},
#   {'source': 'PHF15', 'target': 'DNASE1', 'value': 1},
#   {'source': 'PHF15', 'target': 'MLYCD', 'value': 1},
#   {'source': 'PHF15', 'target': 'ITPKB', 'value': 1},
# ...
#   {'source': 'PPP6R1', 'target': 'AC006547.13', 'value': 1},
#   {'source': 'RPS16', 'target': 'RPLP1', 'value': 1},
#   {'source': 'RPS16', 'target': 'VKORC1', 'value': 1},
#   {'source': 'FBL', 'target': 'RPS5', 'value': 1},
#   {'source': 'FBL', 'target': 'NR2C2AP', 'value': 1},
#   {'source': 'FBL', 'target': 'C22orf32', 'value': 1},
#   {'source': 'PLD3', 'target': 'JUP', 'value': 1},
#   {'source': 'PLD3', 'target': 'LRRC33', 'value': 1},
#   {'source': 'PIAS4', 'target': 'FAM78A', 'value': 1},
#   {'source': 'PIAS4', 'target': 'RP11-611L7.1', 'value': 1},
#   {'source': 'TBCB', 'target': 'C1orf122', 'value': 1},
#   {'source': 'HNRNPUL1', 'target': 'PKM', 'value': 1},
#   {'source': 'CD79A', 'target': 'POU2AF1', 'value': 1},
#   {'source': 'CD79A', 'target': 'SYVN1', 'value': 1},
#   {'source': 'CD79A', 'target': 'PNOC', 'value': 1},
#   {'source': 'CD79A', 'target': 'IGHD', 'value': 1},
#   {'source': 'RPS19', 'target': 'RPL37A', 'value': 1},
#   {'source': 'RPS19', 'target': 'HAX1', 'value': 1},
#   {'source': 'RPS19', 'target': 'TRMT112', 'value': 1},
#   {'source': 'RPS19', 'target': 'TRAPPC2L', 'value': 1},
#   {'source': 'MEGF8', 'target': 'LAMA5', 'value': 1},
#   {'source': 'MEGF8', 'target': 'SPPL2B', 'value': 1},
#   {'source': 'MEGF8', 'target': 'SLC38A7', 'value': 1},
#   {'source': 'MEGF8', 'target': 'RP11-958N24.1', 'value': 1},
#   {'source': 'LIG1', 'target': 'SHF', 'value': 1},
#   {'source': 'LIG1', 'target': 'MAP3K14-AS1', 'value': 1},
#   {'source': 'RAB3D', 'target': 'TKT', 'value': 1},
#   {'source': 'PPP2R1A', 'target': 'GPR132', 'value': 1},
#   {'source': 'GCDH', 'target': 'SEH1L', 'value': 1},
#   {'source': 'GCDH', 'target': 'SLC5A6', 'value': 1},
#   {'source': 'GCDH', 'target': 'GAMT', 'value': 1},
#   {'source': 'GCDH', 'target': 'SUPT5H', 'value': 1},
#   {'source': 'RPL18A', 'target': 'RPS15', 'value': 1},
#   {'source': 'RPL18A', 'target': 'RPL10', 'value': 1},
#   {'source': 'CRTC1', 'target': 'KAT2A', 'value': 1},
#   {'source': 'CRTC1', 'target': 'RP11-574K11.20', 'value': 1},
#   {'source': 'WBP7', 'target': 'CAMTA2', 'value': 1},
#   {'source': 'WBP7', 'target': 'NFIC', 'value': 1},
#   {'source': 'WBP7', 'target': 'RNF44', 'value': 1},
#   {'source': 'WBP7', 'target': 'GS1-124K5.11', 'value': 1},
#   {'source': 'WBP7', 'target': 'LENG8', 'value': 1},
#   {'source': 'WBP7', 'target': 'AC027601.1', 'value': 1},
#   {'source': 'FKBP8', 'target': 'ADIPOR1', 'value': 1},
#   {'source': 'FKBP8', 'target': 'ANKRD9', 'value': 1},
#   {'source': 'FKBP8', 'target': 'UBXN6', 'value': 1},
#   {'source': 'FKBP8', 'target': 'SLC25A39', 'value': 1},
#   {'source': 'FKBP8', 'target': 'OAZ1', 'value': 1},
#   {'source': 'FKBP8', 'target': 'E2F1', 'value': 1},
#   {'source': 'FKBP8', 'target': 'SLC38A5', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'AEBP1', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'CYBASC3', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'PLD4', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'ZNF775', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'MYO1C', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'CAPN3', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'RSPH9', 'value': 1},
#   {'source': 'SIPA1L3', 'target': 'FADS3', 'value': 1},
#   {'source': 'AVL9', 'target': 'ZYG11B', 'value': 1},
#   {'source': 'AVL9', 'target': 'SMAD4', 'value': 1},
#   {'source': 'AVL9', 'target': 'AC096772.6', 'value': 1},
#   {'source': 'NAMPT', 'target': 'VNN2', 'value': 1},
#   {'source': 'NAMPT', 'target': 'MNDA', 'value': 1},
#   {'source': 'NAMPT', 'target': 'FARSA', 'value': 1},
#   {'source': 'NAMPT', 'target': 'GK', 'value': 1},
#   {'source': 'NAMPT', 'target': 'ACSL4', 'value': 1},
#   {'source': 'NAMPT', 'target': 'LMNB1', 'value': 1},
#   {'source': 'NAMPT', 'target': 'GCA', 'value': 1},
#   {'source': 'NAMPT', 'target': 'SDCBP', 'value': 1},
#   {'source': 'NAMPT', 'target': 'RAB5A', 'value': 1},
#   {'source': 'NAMPT', 'target': 'TDP2', 'value': 1},
#   {'source': 'NAMPT', 'target': 'ST8SIA4', 'value': 1},
#   {'source': 'TWISTNB', 'target': 'HSPD1', 'value': 1},
#   {'source': 'TWISTNB', 'target': 'MAPK6', 'value': 1},
#   {'source': 'HBP1', 'target': 'KBTBD2', 'value': 1},
#   {'source': 'HBP1', 'target': 'CCDC28A', 'value': 1},
#   {'source': 'OGDH', 'target': 'MICALL1', 'value': 1},
#   {'source': 'LFNG', 'target': 'ZNF469', 'value': 1},
#   {'source': 'LFNG', 'target': 'DOK2', 'value': 1},
#   {'source': 'PDAP1', 'target': 'NOL3', 'value': 1},
#   {'source': 'PDAP1', 'target': 'TNXB', 'value': 1},
#   {'source': 'SNX8', 'target': 'LGMN', 'value': 1},
#   {'source': 'AHR', 'target': 'SOWAHC', 'value': 1},
#   {'source': 'AHR', 'target': 'WDR49', 'value': 1},
#   {'source': 'URGCP', 'target': 'RNMTL1', 'value': 1},
#   {'source': 'URGCP', 'target': 'FAM134C', 'value': 1},
#   {'source': 'URGCP', 'target': 'ICMT', 'value': 1},
#   {'source': 'URGCP', 'target': 'RIMS3', 'value': 1},
#   {'source': 'URGCP', 'target': 'RRP7A', 'value': 1},
#   {'source': 'URGCP', 'target': 'SNAP47', 'value': 1},
#   {'source': 'AEBP1', 'target': 'PNPLA7', 'value': 1},
#   {'source': 'AEBP1', 'target': 'CACNA1F', 'value': 1},
#   {'source': 'AKNA', 'target': 'ATP2A3', 'value': 1},
#   {'source': 'AKNA', 'target': 'CIC', 'value': 1},
#   {'source': 'AKNA', 'target': 'EPS15L1', 'value': 1},
#   {'source': 'AKNA', 'target': 'TBC1D10B', 'value': 1},
#   {'source': 'AKNA', 'target': 'GAK', 'value': 1},
#   {'source': 'AKNA', 'target': 'SAMD4B', 'value': 1},
#   {'source': 'AKNA', 'target': 'PRRC2A', 'value': 1},
#   {'source': 'AKNA', 'target': 'ATF6B', 'value': 1},
#   {'source': 'AKNA', 'target': 'RP11-367J11.2', 'value': 1},
#   {'source': 'AKNA', 'target': 'NLRP1', 'value': 1},
#   {'source': 'AKNA', 'target': 'CLSTN3', 'value': 1},
#   {'source': 'AKNA', 'target': 'SETD1B', 'value': 1},
#   {'source': 'AKNA', 'target': 'BEAN1', 'value': 1},
#   {'source': 'AKNA', 'target': 'ERN1', 'value': 1},
#   {'source': 'AKNA', 'target': 'RP11-304F15.3', 'value': 1},
#   {'source': 'AKNA', 'target': 'ZSWIM8', 'value': 1},
#   {'source': 'AKNA', 'target': 'PRR7-AS1', 'value': 1},
#   {'source': 'AKNA', 'target': 'MAPK13', 'value': 1},
#   {'source': 'AKNA', 'target': 'ARHGAP1', 'value': 1},
#   {'source': 'AKNA', 'target': 'GUSBP11', 'value': 1},
#   {'source': 'AKNA', 'target': 'CDK11B', 'value': 1},
#   {'source': 'AKNA', 'target': 'SKIV2L', 'value': 1},
#   {'source': 'AKNA', 'target': 'MAP7D1', 'value': 1},
#   {'source': 'AKNA', 'target': 'TTLL3', 'value': 1},
#   {'source': 'AKNA', 'target': 'CSAD', 'value': 1},
#   {'source': 'AKNA', 'target': 'AC132872.1', 'value': 1},
#   {'source': 'AKNA', 'target': 'U73169.1', 'value': 1},
#   {'source': 'AKNA', 'target': 'RP4-742C19.8', 'value': 1},
#   {'source': 'AKNA', 'target': 'C1orf132', 'value': 1},
#   {'source': 'AKNA', 'target': 'FAM193B', 'value': 1},
#   {'source': 'AKNA', 'target': 'LRSAM1', 'value': 1},
#   {'source': 'EDF1', 'target': 'SNRPD3', 'value': 1},
#   {'source': 'EDF1', 'target': 'NHP2L1', 'value': 1},
#   {'source': 'EDF1', 'target': 'RPS19', 'value': 1},
#   {'source': 'EDF1', 'target': 'FKBP2', 'value': 1},
#   {'source': 'EDF1', 'target': 'SNRPB', 'value': 1},
#   {'source': 'EDF1', 'target': 'PEBP1', 'value': 1},
#   {'source': 'EDF1', 'target': 'SNX17', 'value': 1},
#   {'source': 'EDF1', 'target': 'APRT', 'value': 1},
#   {'source': 'EDF1', 'target': 'LAGE3', 'value': 1},
#   {'source': 'EDF1', 'target': 'POLR2G', 'value': 1},
#   {'source': 'EDF1', 'target': 'HSD17B10', 'value': 1},
#   {'source': 'EIF3A', 'target': 'ATRN', 'value': 1},
#   {'source': 'EIF3A', 'target': 'IARS2', 'value': 1},
#   {'source': 'EIF3A', 'target': 'YTHDF2', 'value': 1},
#   {'source': 'EIF3A', 'target': 'RNF168', 'value': 1},
#   {'source': 'NSMCE4A', 'target': 'NGDN', 'value': 1},
#   {'source': 'NSMCE4A', 'target': 'EBNA1BP2', 'value': 1},
#   {'source': 'NSMCE4A', 'target': 'RBM34', 'value': 1},
#   {'source': 'BMPR1A', 'target': 'NIPA1', 'value': 1},
#   {'source': 'C10orf2', 'target': 'POLR3K', 'value': 1},
#   {'source': 'LZTS2', 'target': 'NARFL', 'value': 1},
#   {'source': 'SUFU', 'target': 'USP22', 'value': 1},
#   {'source': 'SUFU', 'target': 'SEPN1', 'value': 1},
#   {'source': 'LARP4B', 'target': 'DTNBP1', 'value': 1},
#   {'source': 'LARP4B', 'target': 'RP11-57H14.4', 'value': 1},
#   {'source': 'LARP4B', 'target': 'RALGPS1', 'value': 1},
#   {'source': 'BCCIP', 'target': 'DNAJC2', 'value': 1},
#   {'source': 'BCCIP', 'target': 'MPHOSPH10', 'value': 1},
#   {'source': 'FAM208B', 'target': 'MLLT10', 'value': 1},
#   {'source': 'FAM208B', 'target': 'PREP', 'value': 1},
#   {'source': 'FAM208B', 'target': 'ZC3H7A', 'value': 1},
#   {'source': 'FAM208B', 'target': 'FILIP1L', 'value': 1},
#   {'source': 'FAM208B', 'target': 'PDS5A', 'value': 1},
#   {'source': 'FAM208B', 'target': 'UBE3D', 'value': 1},
#   {'source': 'FAM208B', 'target': 'GPHN', 'value': 1},
#   {'source': 'FAM208B', 'target': 'STX17', 'value': 1},
#   {'source': 'FAM208B', 'target': 'ERAP1', 'value': 1},
#   {'source': 'RPL28', 'target': 'SZRD1', 'value': 1},
#   {'source': 'AATF', 'target': 'KLHL12', 'value': 1},
#   {'source': 'MLLT6', 'target': 'ZNF496', 'value': 1},
#   {'source': 'MLLT6', 'target': 'APOBEC3D', 'value': 1},
#   {'source': 'MLLT6', 'target': 'NAA40', 'value': 1},
#   {'source': 'MLLT6', 'target': 'ASPSCR1', 'value': 1},
#   {'source': 'MLLT6', 'target': 'DMWD', 'value': 1},
#   {'source': 'MLLT6', 'target': 'PLXNA3', 'value': 1},
#   {'source': 'UBTF', 'target': 'PRPF6', 'value': 1},
#   {'source': 'CAMTA2', 'target': 'RNF126', 'value': 1},
#   {'source': 'CAMTA2', 'target': 'RP11-848G14.5', 'value': 1},
#   {'source': 'RAI1', 'target': 'ATP8B3', 'value': 1},
#   {'source': 'CYTH1', 'target': 'BRPF1', 'value': 1},
#   {'source': 'MRPL27', 'target': 'COX6C', 'value': 1},
#   {'source': 'LAMTOR3', 'target': 'ZNF701', 'value': 1},
#   {'source': 'LAMTOR3', 'target': 'MMADHC', 'value': 1},
#   {'source': 'ZNF330', 'target': 'TRMT6', 'value': 1},
#   {'source': 'UFSP2', 'target': 'PUS3', 'value': 1},
#   {'source': 'MS4A6A', 'target': 'RIN2', 'value': 1},
#   {'source': 'MS4A6A', 'target': 'WDR49', 'value': 1},
#   {'source': 'TMEM109', 'target': 'HSPBP1', 'value': 1},
#   {'source': 'TMEM109', 'target': 'KEAP1', 'value': 1},
#   {'source': 'FBXO3', 'target': 'TM2D3', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'SEL1L3', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'CPNE5', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'BTNL9', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'PARM1', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'RP11-381P6.1', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'DERL3', 'value': 1},
#   {'source': 'POU2AF1', 'target': 'BHLHE41', 'value': 1},
#   {'source': 'PRPF40B', 'target': 'SYCE2', 'value': 1},
#   {'source': 'CLEC2B', 'target': 'SYF2', 'value': 1},
#   {'source': 'CLEC2B', 'target': 'NPLOC4', 'value': 1},
#   {'source': 'OAS3', 'target': 'TOR1B', 'value': 1},
#   {'source': 'OAS3', 'target': 'OAS1', 'value': 1},
#   {'source': 'OAS3', 'target': 'ZCCHC2', 'value': 1},
#   {'source': 'OAS3', 'target': 'SIGLEC1', 'value': 1},
#   {'source': 'OAS3', 'target': 'AGRN', 'value': 1},
#   {'source': 'OAS3', 'target': 'OAS2', 'value': 1},
#   {'source': 'ARHGDIB', 'target': 'AC009961.3', 'value': 1},
#   {'source': 'ARHGDIB', 'target': 'BIN2', 'value': 1},
#   {'source': 'DDX55', 'target': 'ZNF234', 'value': 1},
#   {'source': 'DDX55', 'target': 'ABCB8', 'value': 1},
#   {'source': 'KRR1', 'target': 'ANKRA2', 'value': 1},
#   {'source': 'KRR1', 'target': 'UBE2A', 'value': 1},
#   {'source': 'KRR1', 'target': 'SLC35B3', 'value': 1},
#   {'source': 'CHD4', 'target': 'ACLY', 'value': 1},
#   {'source': 'USP5', 'target': 'UNC45A', 'value': 1},
#   {'source': 'USP5', 'target': 'TSR2', 'value': 1},
#   {'source': 'USP5', 'target': 'SHMT2', 'value': 1},
#   {'source': 'USP5', 'target': 'LRRC47', 'value': 1},
#   {'source': 'USP5', 'target': 'TEF', 'value': 1},
#   {'source': 'USP5', 'target': 'DPP3', 'value': 1},
#   {'source': 'USP5', 'target': 'GRWD1', 'value': 1},
#   {'source': 'USP5', 'target': 'LONP1', 'value': 1},
#   {'source': 'USP5', 'target': 'PRMT1', 'value': 1},
#   {'source': 'USP5', 'target': 'PES1', 'value': 1},
#   {'source': 'USP5', 'target': 'RP11-127L20.6', 'value': 1},
#   {'source': 'RAB35', 'target': 'CD2BP2', 'value': 1},
#   {'source': 'FGFR1OP2', 'target': 'COPS2', 'value': 1},
#   {'source': 'FGFR1OP2', 'target': 'TRIM23', 'value': 1},
#   {'source': 'FGFR1OP2', 'target': 'ARPC1A', 'value': 1},
#   {'source': 'FGFR1OP2', 'target': 'RNF185', 'value': 1},
#   {'source': 'FGFR1OP2', 'target': 'PDCD10', 'value': 1},
#   {'source': 'NEDD9', 'target': 'SIPA1L1', 'value': 1},
#   {'source': 'SERINC1', 'target': 'GALNT1', 'value': 1},
#   {'source': 'SERINC1', 'target': 'RP11-361F15.2', 'value': 1},
#   {'source': 'MAPK14', 'target': 'CD177', 'value': 1},
#   {'source': 'MAPK14', 'target': 'TLR5', 'value': 1},
#   {'source': 'MAPK14', 'target': 'CDC42EP3', 'value': 1},
#   {'source': 'MAPK14', 'target': 'RP1-179N16.3', 'value': 1},
#   {'source': 'MAPK14', 'target': 'PHTF1', 'value': 1},
#   {'source': 'SRSF3', 'target': 'SRI', 'value': 1},
#   {'source': 'SRSF3', 'target': 'FAM175A', 'value': 1},
#   {'source': 'SOD2', 'target': 'PRKAR1A', 'value': 1},
#   {'source': 'SOD2', 'target': 'RALB', 'value': 1},
#   {'source': 'SOD2', 'target': 'F2RL1', 'value': 1},
#   {'source': 'ASCC3', 'target': 'WEE1', 'value': 1},
#   {'source': 'ASCC3', 'target': 'ZNF197', 'value': 1},
#   {'source': 'ASCC3', 'target': 'KIFAP3', 'value': 1},
#   {'source': 'ASCC3', 'target': 'INTS7', 'value': 1},
#   {'source': 'ASCC3', 'target': 'ZHX1', 'value': 1},
#   {'source': 'TFEB', 'target': 'ABI3', 'value': 1},
#   {'source': 'TFEB', 'target': 'PDLIM2', 'value': 1},
#   {'source': 'VEGFA', 'target': 'CTD-3035D6.1', 'value': 1},
#   {'source': 'CEP72', 'target': 'ACBD4', 'value': 1},
#   {'source': 'HMGCR', 'target': 'POLR3E', 'value': 1},
#   {'source': 'CLK4', 'target': 'ZNF354A', 'value': 1},
#   {'source': 'ITK', 'target': 'RP11-292F22.6', 'value': 1},
#   {'source': 'ARSB', 'target': 'IGHEP2', 'value': 1},
#   {'source': 'CLINT1', 'target': 'PLIN2', 'value': 1},
#   {'source': 'CLINT1', 'target': 'ACTR8', 'value': 1},
#   {'source': 'CLINT1', 'target': 'EIF4E2', 'value': 1},
#   {'source': 'CLINT1', 'target': 'CALU', 'value': 1},
#   {'source': 'CLINT1', 'target': 'INPP1', 'value': 1},
#   {'source': 'CLINT1', 'target': 'HSD17B4', 'value': 1},
#   {'source': 'CLINT1', 'target': 'TES', 'value': 1},
#   {'source': 'PPP2CA', 'target': 'WAPAL', 'value': 1},
#   {'source': 'NR3C1', 'target': 'FBXO33', 'value': 1},
#   {'source': 'NR3C1', 'target': 'PAPOLG', 'value': 1},
#   {'source': 'NR3C1', 'target': 'PDE3B', 'value': 1},
#   {'source': 'NR3C1', 'target': 'ITCH', 'value': 1},
#   {'source': 'HMGXB3', 'target': 'YTHDF1', 'value': 1},
#   {'source': 'HMGXB3', 'target': 'NONO', 'value': 1},
#   {'source': 'HMGXB3', 'target': 'RP11-178G16.4', 'value': 1},
#   {'source': 'HRH2', 'target': 'EMR2', 'value': 1},
#   {'source': 'HRH2', 'target': 'KIAA0317', 'value': 1},
#   {'source': 'HRH2', 'target': 'SIRPA', 'value': 1},
#   {'source': 'BCL6', 'target': 'RP11-211G3.2', 'value': 1},
#   {'source': 'BCL6', 'target': 'PPP4R1L', 'value': 1},
#   {'source': 'BCL6', 'target': 'PHF21A', 'value': 1},
#   {'source': 'BCL6', 'target': 'APBB1IP', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'TNFSF13B', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'PSENEN', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'HLX', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'FUT8', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'MIR223', 'value': 1},
#   {'source': 'PFKFB4', 'target': 'TMEM48', 'value': 1},
#   {'source': 'GNAI2', 'target': 'DNAJC5', 'value': 1},
#   {'source': 'GNAI2', 'target': 'RAB35', 'value': 1},
#   {'source': 'GNAI2', 'target': 'ARPC1B', 'value': 1},
#   {'source': 'GNAI2', 'target': 'WDR1', 'value': 1},
#   {'source': 'GNAI2', 'target': 'EHD1', 'value': 1},
#   {'source': 'GNAI2', 'target': 'ITGB2', 'value': 1},
#   {'source': 'GNAI2', 'target': 'CDC42EP4', 'value': 1},
#   {'source': 'GNAI2', 'target': 'SCYL1', 'value': 1},
#   {'source': 'GNAI2', 'target': 'CHMP1A', 'value': 1},
#   {'source': 'RPL24', 'target': 'RPS20', 'value': 1},
#   {'source': 'RPL24', 'target': 'RPS25', 'value': 1},
#   {'source': 'RPL24', 'target': 'RPL35', 'value': 1},
#   {'source': 'RPL24', 'target': 'SOD1', 'value': 1},
#   ...]}

# %%
with open('complete_data_icave_format.json', 'w') as fp:
    json.dump(final, fp)

# %% [markdown]
# ________

# %% [markdown]
# # Modules

# %% [markdown]
# ### BcellM7

# %%
BcellM7_KD = {}
for kd, gene in zip(KDs["BcellM7_KD"], KDs["geneName_KD"]):
    BcellM7_KD[gene] = kd

len(BcellM7_KD), len(nodes)
# Out:
# (904, 13305)

# %%
## THERE IS NOT INFORMATION ABOUT KD FOR ALL NODES. I SET THEM TO 0 IF NON EXISTENT IN THE KD DOCUMENT

for n in nodes:
    if n not in BcellM7_KD:
        BcellM7_KD[n] = 0

len(BcellM7_KD), len(nodes)
# Out:
# (13307, 13305)

# %%
links_BcellM7 = []
nodes_BcellM7 = []

for parent, child in links:
    if nodes_and_groups[parent] == "BcellM7" or nodes_and_groups[child] == "BcellM7":
        links_BcellM7.append([parent, child])
        nodes_BcellM7.append([parent, nodes_and_groups[parent], BcellM7_KD[parent]])
        nodes_BcellM7.append([child, nodes_and_groups[child], BcellM7_KD[child]]) 
        
nodes_BcellM7 = set(map(tuple, nodes_BcellM7))

# %%
len(links)
# Out:
# 17485

# %%
len(nodes_and_groups)
# Out:
# 13305

# %%
BcellM7_final = {"nodes": [], "links": []}

for node, group, kd in nodes_BcellM7:
    BcellM7_final["nodes"] += [{"id": node, "group": group, "kd": kd}]

for parent, child in links_BcellM7:
    BcellM7_final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
with open('BcellM7_final.json', 'w') as fp:
    json.dump(BcellM7_final, fp)

# %%
# SourceID	SourceNodeColor	SourceNodeSize	TargetID	TargetNodeColor	TargetNodeSize

#----- Color
# none = 0
# NKM4 = 1
# BcellM7 = 2
# MonoM6 = 3
# NKM13 = 4
# NKM9 = 5

#----- Size
# none = 0
# kd = 1

# %%
def color_trans (module):
    if module == "none":
        return 0
    if module == "NKM4":
        return 1
    if module == "BcellM7":
        return 2
    if module == "MonoM6":
        return 3
    if module == "NKM13":
        return 4
    if module == "NKM9":
        return 5
    
def size_trans (size):
    if size == 0:
        return 5
    if size == 1:
        return 15

# %%
total = len(links_BcellM7)

bcellDF = pd.DataFrame(links_BcellM7, columns=['SourceID','TargetID'])
bcellDF["SourceNodeColor"] = [0] * total
bcellDF["SourceNodeSize"] = [0] * total
bcellDF["TargetNodeColor"] = [0] * total
bcellDF["TargetNodeSize"] = [0] * total

for ID, color, size in nodes_BcellM7:
    indexes_s = bcellDF[bcellDF["SourceID"] == ID].index.values
    for s in indexes_s:
        bcellDF["SourceNodeColor"][s] = color_trans(color)
        bcellDF["SourceNodeSize"][s] = size_trans(size)
    indexes_t = bcellDF[bcellDF["TargetID"] == ID].index.values
    for t in indexes_t:
        bcellDF["TargetNodeColor"][t] = color_trans(color)
        bcellDF["TargetNodeSize"][t] = size_trans(size)
# Out:
# <ipython-input-104-137c68039e12>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcellDF["TargetNodeColor"][t] = color_trans(color)
# <ipython-input-104-137c68039e12>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcellDF["TargetNodeSize"][t] = size_trans(size)
# <ipython-input-104-137c68039e12>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcellDF["SourceNodeColor"][s] = color_trans(color)
# <ipython-input-104-137c68039e12>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcellDF["SourceNodeSize"][s] = size_trans(size)

# %%
bcellDF
# Out:
#            SourceID   TargetID  SourceNodeColor  SourceNodeSize  \
# 0           FAM214B  C17orf103                2               5
# 1           FAM214B      WDR45                2               5
# 2              IL32        CD2                0               5
# 3             RPS20        SNN                0               5
# 4          TRAF3IP3   KIAA0907                3               5
# ...             ...        ...              ...             ...
# 2076          SPTA1     SPECC1                0               5
# 2077  RP11-473M20.8      MMP25                0               5
# 2078  RP11-439A17.9       STK3                0               5
# 2079  RP11-707P17.2      DMXL2                0               5
# 2080          NAA20      IFT57                0               5
#
#       TargetNodeColor  TargetNodeSize
# 0                   0               5
# 1                   0               5
# 2                   2               5
# 3                   2               5
# 4                   2               5
# ...               ...             ...
# 2076                2               5
# 2077                2               5
# 2078                2               5
# 2079                2               5
# 2080                2               5
#
# [2081 rows x 6 columns]

# %%
bcellDF.to_csv ('bcellDF.csv', index =False, header=True)

# %% [markdown]
# ### MonoM6

# %%
MonoM6_KD = {}
for kd, gene in zip(KDs["MonoM6_KD"], KDs["geneName_KD"]):
    MonoM6_KD[gene] = kd

len(MonoM6_KD), len(nodes)
# Out:
# (904, 13305)

# %%
## THERE IS NOT INFORMATION ABOUT KD FOR ALL NODES. I SET THEM TO 0 IF NON EXISTENT IN THE KD DOCUMENT

for n in nodes:
    if n not in MonoM6_KD:
        MonoM6_KD[n] = 0

len(MonoM6_KD), len(nodes)
# Out:
# (13307, 13305)

# %%
links_MonoM6 = []
nodes_MonoM6 = []

for parent, child in links:
    if nodes_and_groups[parent] == "MonoM6" or nodes_and_groups[child] == "MonoM6":
        links_MonoM6.append([parent, child])
        nodes_MonoM6.append([parent, nodes_and_groups[parent], MonoM6_KD[parent]])
        nodes_MonoM6.append([child, nodes_and_groups[child], MonoM6_KD[child]])    

nodes_MonoM6 = set(map(tuple, nodes_MonoM6))

# %%
MonoM6_final = {"nodes": [], "links": []}

for node, group, kd in nodes_MonoM6:
    MonoM6_final["nodes"] += [{"id": node, "group": group, "kd": kd}]

for parent, child in links_MonoM6:
    MonoM6_final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
with open('MonoM6_final.json', 'w') as fp:
    json.dump(MonoM6_final, fp)

# %% [markdown]
# ### NKM13

# %%
NKM13_KD = {}
for kd, gene in zip(KDs["NKM13_KD"], KDs["geneName_KD"]):
    NKM13_KD[gene] = kd

len(NKM13_KD), len(nodes)
# Out:
# (904, 13305)

# %%
## THERE IS NOT INFORMATION ABOUT KD FOR ALL NODES. I SET THEM TO 0 IF NON EXISTENT IN THE KD DOCUMENT

for n in nodes:
    if n not in NKM13_KD:
        NKM13_KD[n] = 0

len(NKM13_KD), len(nodes)
# Out:
# (13307, 13305)

# %%
links_NKM13 = []
nodes_NKM13 = []

for parent, child in links:
    if nodes_and_groups[parent] == "NKM13" or nodes_and_groups[child] == "NKM13":
        links_NKM13.append([parent, child])
        nodes_NKM13.append([parent, nodes_and_groups[parent], NKM13_KD[parent]])
        nodes_NKM13.append([child, nodes_and_groups[child], NKM13_KD[child]]) 

nodes_NKM13 = set(map(tuple, nodes_NKM13))

# %%
NKM13_final = {"nodes": [], "links": []}

for node, group, kd in nodes_NKM13:
    NKM13_final["nodes"] += [{"id": node, "group": group, "kd": kd}]

for parent, child in links_NKM13:
    NKM13_final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
with open('NKM13_final.json', 'w') as fp:
    json.dump(NKM13_final, fp)

# %% [markdown]
# ### NKM9

# %%
NKM9_KD = {}
for kd, gene in zip(KDs["NKM9_KD"], KDs["geneName_KD"]):
    NKM9_KD[gene] = kd

len(NKM9_KD), len(nodes)
# Out:
# (904, 13305)

# %%
## THERE IS NOT INFORMATION ABOUT KD FOR ALL NODES. I SET THEM TO 0 IF NON EXISTENT IN THE KD DOCUMENT

for n in nodes:
    if n not in NKM9_KD:
        NKM9_KD[n] = 0

len(NKM9_KD), len(nodes)
# Out:
# (13307, 13305)

# %%
links_NKM9 = []
nodes_NKM9 = []

for parent, child in links:
    if nodes_and_groups[parent] == "NKM9" or nodes_and_groups[child] == "NKM9":
        links_NKM9.append([parent, child])
        nodes_NKM9.append([parent, nodes_and_groups[parent], NKM9_KD[parent]])
        nodes_NKM9.append([child, nodes_and_groups[child], NKM9_KD[child]])  

nodes_NKM9 = set(map(tuple, nodes_NKM9))

# %%
NKM9_final = {"nodes": [], "links": []}

for node, group, kd in nodes_NKM9:
    NKM9_final["nodes"] += [{"id": node, "group": group, "kd": kd}]

for parent, child in links_NKM9:
    NKM9_final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
with open('NKM9_final.json', 'w') as fp:
    json.dump(NKM9_final, fp)

# %% [markdown]
# ### NKM4

# %%
NKM4_KD = {} ## THIS SPECIFIC MODULE DONT HAVE KD.
#for kd, gene in zip(KDs["BcellM7_KD"], KDs["geneName_KD"]):
#    BcellM7_KD[gene] = kd

#len(BcellM7_KD), len(nodes)

# %%
## THERE IS NOT INFORMATION ABOUT KD FOR ALL NODES. I SET THEM TO 0 IF NON EXISTENT IN THE KD DOCUMENT

for n in nodes:
    if n not in NKM4_KD:
        NKM4_KD[n] = 0

len(NKM4_KD), len(nodes)
# Out:
# (13305, 13305)

# %%
links_NKM4 = []
nodes_NKM4 = []

for parent, child in links:
    if nodes_and_groups[parent] == "NKM4" or nodes_and_groups[child] == "NKM4":
        links_NKM4.append([parent, child])
        nodes_NKM4.append([parent, nodes_and_groups[parent], NKM4_KD[parent]])
        nodes_NKM4.append([child, nodes_and_groups[child], NKM4_KD[child]]) 
        
nodes_NKM4 = set(map(tuple, nodes_NKM4))

# %%
NKM4_final = {"nodes": [], "links": []}

for node, group, kd in nodes_NKM4:
    NKM4_final["nodes"] += [{"id": node, "group": group, "kd": kd}]

for parent, child in links_NKM4:
    NKM4_final["links"] += [{"source": parent, "target": child, "value": 1}]

# %%
with open('NKM4_final.json', 'w') as fp:
    json.dump(NKM4_final, fp)
